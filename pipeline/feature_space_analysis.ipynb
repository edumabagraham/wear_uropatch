# %%
from sklearn.decomposition import PCA
import numpy as np
import optuna
import seaborn as sns
from sklearn.pipeline import Pipeline
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                        roc_curve, auc, roc_auc_score, log_loss)
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder, label_binarize
import pandas as pd
import matplotlib.pyplot as plt
import warnings
from typing import Dict, List, Any, Tuple
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GroupKFold, GroupShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score, roc_auc_score
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn.feature_selection import RFECV
from sklearn.feature_selection import SelectKBest, chi2, f_classif, mutual_info_classif
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.model_selection import train_test_split

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# data_path = '/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/pipeline/modified/feature_extracted_data/two_class_pp_5s_0.5.csv'
data_path = '/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/pipeline/feature_extracted_data/three_class_pp_5s_0.5.csv'
features = pd.read_csv(data_path)
features.drop(columns=['center_time', 'start_time', 'end_time'], inplace=True)

label_encoder = LabelEncoder()
labels = label_encoder.fit_transform(features['label'])

features['label'] = labels

X = features.drop(columns=['experiment_id'])
y = features['label']
groups = features['experiment_id']

# %%
columns = X.columns
columns_list = list(columns)

# %%
target = 'label'

# %%
k = 15 # Number of features in the heatmap
cols = X[columns].corr().nlargest(k, target)[target].index
cm = X[cols].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
def generate_accuracy_and_heatmap(model, X, y):
    y_pred = model.predict(X)
    
    # Define class order with 'void' first (even though it's encoded as 1)
    # classes_ordered = ['void', 'non-void']  # Display order you want
    # labels_ordered = [1, 0]  # Corresponding encoded values
    
    classes_ordered = ['pre-void','void', 'post-void']  # Display order you want
    labels_ordered = [1, 2, 0]  # Corresponding encoded values
    
    ac = accuracy_score(y, y_pred)
    # f_score = f1_score(y, y_pred, average='macro', pos_label=1)  # void as positive
    f_score = f1_score(y, y_pred, average='macro', pos_label=2)  # void as positive
    
    print("Accuracy is: ", ac)
    print("F1 Score is: ", f_score)
    print('\n')
    
    # Crosstab
    print(pd.crosstab(pd.Series(y_pred, name='Predicted'), 
                    pd.Series(y, name='Actual')))
    print('\n')
    
    # Confusion matrix with void on top
    cm = confusion_matrix(y, y_pred, labels=labels_ordered)  # [1, 0] order
    cm_display = ConfusionMatrixDisplay(confusion_matrix=cm, 
                                    display_labels=classes_ordered)  # ['void', 'non-void']
    cm_display.plot()
    plt.show()
    
    # Classification report with void first
    report = classification_report(y, y_pred, 
                                labels=labels_ordered,  # [1, 0]
                                target_names=classes_ordered)  # ['void', 'non-void']
    print("Classification Report:")
    print(report)
    
    return 1

# %%
X = features.drop(columns=['label', 'experiment_id'])
y = features['label']
groups = features['experiment_id']

# %%
splitter = GroupShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
train_idx, test_idx = next(splitter.split(X, y, groups))

X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

# %%
from xgboost import XGBClassifier
model = XGBClassifier()

model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
generate_accuracy_and_heatmap(model, X_test, y_test)
# Out:
# Accuracy is:  0.5185185185185185
# F1 Score is:  0.510543882513748
#
#
# Actual      0  1   2
# Predicted
# 0          10  1   5
# 1           2  1  14
# 2           0  4   6
# Classification Report:
#               precision    recall  f1-score   support
#
#     pre-void       0.31      0.57      0.40        46
#         void       0.72      0.53      0.61        94
#    post-void       0.56      0.49      0.52       103
#
#     accuracy                           0.52       243
#    macro avg       0.53      0.53      0.51       243
# weighted avg       0.57      0.52      0.53       243
# 1

# %%
# select_feature = SelectKBest(chi2, k=5).fit(X_train, y_train)
select_feature = SelectKBest(f_classif, k=5).fit(X_train, y_train)

# %%
# Ensure full display
pd.set_option("display.max_rows", None)   # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", None)    # No wrapping
pd.set_option("display.max_colwidth", None)  # Show long column values

selected_features_df = pd.DataFrame({'Feature':list(X_train.columns),
                                    'Scores':select_feature.scores_})
selected_features_df.sort_values(by='Scores', ascending=False)
# Out:
#                           Feature     Scores
# 104        gyr_y_hjorth_frequency  75.673145
# 101         gyr_y_spectral_spread  71.743960
# 12        acc_x_spectral_flatness  70.653630
# 122        gyr_z_hjorth_frequency  70.087865
# 119         gyr_z_spectral_spread  65.791367
# 14         acc_x_hjorth_frequency  61.906949
# 90      gyr_y_permutation_entropy  61.655204
# 11          acc_x_spectral_spread  58.967366
# 102       gyr_y_spectral_flatness  57.784648
# 100       gyr_y_spectral_centroid  53.495998
# 91         gyr_y_spectral_entropy  53.023337
# 93                      gyr_y_std  51.638998
# 95                      gyr_y_rms  50.806410
# 129                   gyr_mag_std  50.031604
# 108     gyr_z_permutation_entropy  48.937994
# 10        acc_x_spectral_centroid  48.431454
# 5                       acc_x_rms  47.739298
# 7                       acc_x_min  47.262025
# 118       gyr_z_spectral_centroid  47.198110
# 137       gyr_mag_spectral_spread  46.914562
# 120       gyr_z_spectral_flatness  46.595078
# 94                    gyr_y_range  45.963226
# 131                   gyr_mag_rms  45.759448
# 3                       acc_x_std  45.634316
# 130                 gyr_mag_range  45.546989
# 4                     acc_x_range  45.430937
# 134                   gyr_mag_max  45.389075
# 140      gyr_mag_hjorth_frequency  45.248116
# 112                   gyr_z_range  42.808438
# 113                     gyr_z_rms  42.611559
# 109        gyr_z_spectral_entropy  42.503646
# 111                     gyr_z_std  42.472917
# 97                      gyr_y_min  41.158121
# 56                   acc_mag_mean  41.037157
# 128                  gyr_mag_mean  40.786119
# 59                    acc_mag_rms  39.923721
# 0       acc_x_permutation_entropy  39.778486
# 126   gyr_mag_permutation_entropy  39.419262
# 132                   gyr_mag_var  38.775652
# 116                     gyr_z_max  38.212650
# 50         acc_z_hjorth_frequency  37.767212
# 1          acc_x_spectral_entropy  36.970847
# 135           gyr_mag_time_energy  36.201540
# 136     gyr_mag_spectral_centroid  36.087438
# 99              gyr_y_time_energy  35.559947
# 115                     gyr_z_min  35.446316
# 107                     gyr_y_snr  35.146943
# 96                      gyr_y_var  34.838546
# 80                      gyr_x_max  33.858281
# 103    gyr_y_peak_frequency_ratio  33.526590
# 77                      gyr_x_rms  33.254021
# 9               acc_x_time_energy  33.149013
# 81              gyr_x_time_energy  33.117836
# 127      gyr_mag_spectral_entropy  32.780971
# 105       gyr_y_spectral_skewness  32.629353
# 139  gyr_mag_peak_frequency_ratio  32.505886
# 63            acc_mag_time_energy  32.390907
# 138     gyr_mag_spectral_flatness  31.772185
# 141     gyr_mag_spectral_skewness  31.156643
# 75                      gyr_x_std  30.488142
# 62                    acc_mag_max  30.433782
# 76                    gyr_x_range  30.365863
# 98                      gyr_y_max  30.134447
# 78                      gyr_x_var  30.018908
# 143                   gyr_mag_snr  28.977609
# 123       gyr_z_spectral_skewness  27.909633
# 8                       acc_x_max  27.773004
# 32         acc_y_hjorth_frequency  27.013199
# 41                      acc_z_rms  27.003812
# 58                  acc_mag_range  26.984003
# 45              acc_z_time_energy  25.905391
# 86         gyr_x_hjorth_frequency  25.785946
# 117             gyr_z_time_energy  25.519845
# 57                    acc_mag_std  25.404738
# 114                     gyr_z_var  24.579061
# 23                      acc_y_rms  24.459367
# 68       acc_mag_hjorth_frequency  24.378521
# 6                       acc_x_var  24.077848
# 27              acc_y_time_energy  23.087298
# 19         acc_y_spectral_entropy  23.052971
# 36      acc_z_permutation_entropy  22.900105
# 20                     acc_y_mean  22.728856
# 39                      acc_z_std  22.612294
# 125                     gyr_z_snr  22.481761
# 73         gyr_x_spectral_entropy  22.360297
# 42                      acc_z_var  21.868065
# 33        acc_y_spectral_skewness  21.860034
# 121    gyr_z_peak_frequency_ratio  21.653633
# 29          acc_y_spectral_spread  21.477761
# 40                    acc_z_range  21.380152
# 54    acc_mag_permutation_entropy  20.893379
# 79                      gyr_x_min  20.467295
# 13     acc_x_peak_frequency_ratio  20.426884
# 142     gyr_mag_spectral_kurtosis  20.120537
# 83          gyr_x_spectral_spread  20.070942
# 15        acc_x_spectral_skewness  20.048879
# 17                      acc_x_snr  19.351717
# 43                      acc_z_min  18.467258
# 24                      acc_y_var  18.109936
# 106       gyr_y_spectral_kurtosis  17.850818
# 44                      acc_z_max  17.658451
# 60                    acc_mag_var  17.274436
# 87        gyr_x_spectral_skewness  17.231435
# 21                      acc_y_std  17.187123
# 47          acc_z_spectral_spread  17.177065
# 82        gyr_x_spectral_centroid  16.892475
# 2                      acc_x_mean  16.737414
# 38                     acc_z_mean  16.677735
# 61                    acc_mag_min  16.292521
# 18      acc_y_permutation_entropy  15.783903
# 124       gyr_z_spectral_kurtosis  15.324674
# 72      gyr_x_permutation_entropy  15.048923
# 37         acc_z_spectral_entropy  14.929556
# 34        acc_y_spectral_kurtosis  14.238397
# 51        acc_z_spectral_skewness  14.225216
# 25                      acc_y_min  13.861056
# 89                      gyr_x_snr  13.726561
# 65        acc_mag_spectral_spread  13.453722
# 85     gyr_x_peak_frequency_ratio  13.256908
# 22                    acc_y_range  12.526228
# 26                      acc_y_max  12.256838
# 84        gyr_x_spectral_flatness  12.055723
# 46        acc_z_spectral_centroid  11.399244
# 88        gyr_x_spectral_kurtosis  11.278143
# 74                     gyr_x_mean  10.877305
# 48        acc_z_spectral_flatness  10.441710
# 64      acc_mag_spectral_centroid  10.123678
# 52        acc_z_spectral_kurtosis   9.846685
# 55       acc_mag_spectral_entropy   9.676108
# 66      acc_mag_spectral_flatness   8.999806
# 49     acc_z_peak_frequency_ratio   8.715550
# 31     acc_y_peak_frequency_ratio   8.405474
# 53                      acc_z_snr   8.386885
# 28        acc_y_spectral_centroid   8.380759
# 16        acc_x_spectral_kurtosis   8.093034
# 30        acc_y_spectral_flatness   7.958113
# 69      acc_mag_spectral_skewness   6.677822
# 70      acc_mag_spectral_kurtosis   5.951701
# 133                   gyr_mag_min   5.905339
# 35                      acc_y_snr   5.893061
# 110                    gyr_z_mean   3.946727
# 92                     gyr_y_mean   2.122807
# 71                    acc_mag_snr   1.923464
# 67   acc_mag_peak_frequency_ratio   1.695061

# %%
X_train_selected = select_feature.transform(X_train)
X_test_selected = select_feature.transform(X_test)

# %%
X_train.head()
# Out:
#    acc_x_permutation_entropy  acc_x_spectral_entropy  acc_x_mean  acc_x_std  \
# 0                   0.866765                0.727586    0.840159   0.677725
# 1                   0.890166                0.731273    0.624589   0.642153
# 2                   0.889209                0.739116    0.601175   0.685020
# 3                   0.873850                0.796096    0.641500   0.420349
# 4                   0.862154                0.779172    0.509606   0.465049
#
#    acc_x_range  acc_x_rms  acc_x_var  acc_x_min  acc_x_max  acc_x_time_energy  \
# 0     5.252620   1.079434   0.459311  -1.107468   4.145152         349.553614
# 1     5.256642   0.895808   0.412361  -2.270594   2.986048         240.741630
# 2     5.256642   0.911407   0.469252  -2.270594   2.986048         249.199013
# 3     2.781083   0.766952   0.176693  -0.538130   2.242953         176.464517
# 4     3.420627   0.689905   0.216270  -0.886051   2.534576         142.790660
#
#    acc_x_spectral_centroid  acc_x_spectral_spread  acc_x_spectral_flatness  \
# 0                 4.158656               2.930503                 0.054052
# 1                 4.048998               3.764655                 0.078088
# 2                 4.704037               2.983278                 0.051524
# 3                 5.018500               3.613600                 0.075449
# 4                 4.689019               3.661305                 0.099108
#
#    acc_x_peak_frequency_ratio  acc_x_hjorth_frequency  \
# 0                    0.063118                7.894636
# 1                    0.124952                8.436683
# 2                    0.119620                8.623981
# 3                    0.067429                9.589354
# 4                    0.115271                9.219882
#
#    acc_x_spectral_skewness  acc_x_spectral_kurtosis  acc_x_snr  \
# 0                 1.540502                 8.651944 -11.715283
# 1                 1.382417                 5.752017  -8.452904
# 2                 1.339668                 7.635552  -8.668645
# 3                 0.887219                 4.938243 -11.408376
# 4                 1.723525                 7.843379  -8.850883
#
#    acc_y_permutation_entropy  acc_y_spectral_entropy  acc_y_mean  acc_y_std  \
# 0                   0.873660                0.777727    0.327404   0.822896
# 1                   0.885487                0.809894    0.372952   0.854104
# 2                   0.878756                0.825144    0.057683   0.998405
# 3                   0.873321                0.795613   -0.196977   0.937861
# 4                   0.882768                0.778199   -0.313918   0.858072
#
#    acc_y_range  acc_y_rms  acc_y_var  acc_y_min  acc_y_max  acc_y_time_energy  \
# 0     5.993564   0.885637   0.677158  -2.888711   3.104853         235.305608
# 1     5.433529   0.931980   0.729493  -2.577395   2.856134         260.575804
# 2     5.436238   1.000070   0.996813  -2.580104   2.856134         300.042117
# 3     6.027734   0.958323   0.879583  -3.234879   2.792855         275.514906
# 4     6.261525   0.913691   0.736287  -3.234879   3.026646         250.449552
#
#    acc_y_spectral_centroid  acc_y_spectral_spread  acc_y_spectral_flatness  \
# 0                 7.158071               3.290741                 0.109166
# 1                 5.938116               4.715321                 0.094280
# 2                 6.141076               4.222342                 0.114431
# 3                 6.366366               3.897011                 0.077452
# 4                 6.541511               3.262494                 0.108311
#
#    acc_y_peak_frequency_ratio  acc_y_hjorth_frequency  \
# 0                    0.082235                9.545222
# 1                    0.178022               10.040999
# 2                    0.121468                9.836147
# 3                    0.119216                9.655393
# 4                    0.117801                9.366012
#
#    acc_y_spectral_skewness  acc_y_spectral_kurtosis  acc_y_snr  \
# 0                 0.972875                 7.825648 -10.476758
# 1                 0.469354                 3.054223  -6.643864
# 2                 0.628712                 3.814943  -8.592958
# 3                 0.540834                 3.900187  -8.685332
# 4                 1.073996                 6.836500  -8.744193
#
#    acc_z_permutation_entropy  acc_z_spectral_entropy  acc_z_mean  acc_z_std  \
# 0                   0.846072                0.721074    0.636857   0.613261
# 1                   0.868693                0.771123    0.681676   0.764398
# 2                   0.846272                0.759723    0.294342   0.859482
# 3                   0.839034                0.712944   -0.136621   0.764340
# 4                   0.841608                0.767284   -0.486631   0.438700
#
#    acc_z_range  acc_z_rms  acc_z_var  acc_z_min  acc_z_max  acc_z_time_energy  \
# 0     3.226859   0.884125   0.376089  -1.172228   2.054631         234.502923
# 1     3.513453   1.024200   0.584304  -1.262692   2.250760         314.695904
# 2     3.795478   0.908486   0.738709  -1.544718   2.250760         247.603873
# 3     3.937086   0.776454   0.584215  -2.008858   1.928229         180.864038
# 4     3.014478   0.655185   0.192458  -2.008858   1.005620         128.780216
#
#    acc_z_spectral_centroid  acc_z_spectral_spread  acc_z_spectral_flatness  \
# 0                 3.546634               3.407377                 0.060048
# 1                 1.417603               2.704054                 0.018846
# 2                 2.075904               3.349236                 0.030693
# 3                 2.050772               2.844286                 0.025308
# 4                 3.786662               3.168566                 0.040276
#
#    acc_z_peak_frequency_ratio  acc_z_hjorth_frequency  \
# 0                    0.158561                9.129439
# 1                    0.559069                9.186008
# 2                    0.511171                9.049685
# 3                    0.286985                8.876898
# 4                    0.063570                8.690966
#
#    acc_z_spectral_skewness  acc_z_spectral_kurtosis  acc_z_snr  \
# 0                 1.817193                 8.529439  -7.248260
# 1                 2.857263                12.953493   1.030944
# 2                 2.190919                 7.776960   0.194096
# 3                 2.306485                 9.327170  -3.952394
# 4                 1.495104                 5.761784 -11.682233
#
#    acc_mag_permutation_entropy  acc_mag_spectral_entropy  acc_mag_mean  \
# 0                     0.914944                  0.764465      1.491936
# 1                     0.930564                  0.825683      1.506174
# 2                     0.947761                  0.833700      1.482957
# 3                     0.946076                  0.866805      1.340016
# 4                     0.928996                  0.846220      1.186165
#
#    acc_mag_std  acc_mag_range  acc_mag_rms  acc_mag_var  acc_mag_min  \
# 0     0.710869       4.214347     1.652636     0.505334     0.135429
# 1     0.671927       3.371450     1.649256     0.451486     0.099725
# 2     0.676009       3.371450     1.629770     0.456988     0.099725
# 3     0.560209       3.511102     1.452404     0.313834     0.185025
# 4     0.577131       3.438959     1.319116     0.333081     0.257167
#
#    acc_mag_max  acc_mag_time_energy  acc_mag_spectral_centroid  \
# 0     4.349776           819.362145                   4.047900
# 1     3.471175           816.013338                   4.199332
# 2     3.471175           796.845003                   6.163534
# 3     3.696126           632.843462                   7.140626
# 4     3.696126           522.020428                   5.902045
#
#    acc_mag_spectral_spread  acc_mag_spectral_flatness  \
# 0                 4.249233                   0.119478
# 1                 4.796473                   0.103862
# 2                 5.125907                   0.233512
# 3                 5.755759                   0.239916
# 4                 5.741873                   0.250963
#
#    acc_mag_peak_frequency_ratio  acc_mag_hjorth_frequency  \
# 0                      0.163802                 11.685339
# 1                      0.239275                 11.750169
# 2                      0.059532                 12.075869
# 3                      0.135368                 12.763138
# 4                      0.102026                 12.771993
#
#    acc_mag_spectral_skewness  acc_mag_spectral_kurtosis  acc_mag_snr  \
# 0                   1.914418                   8.079383    -7.079883
# 1                   1.216830                   4.228505    -5.023305
# 2                   1.649588                   6.081581   -11.985897
# 3                   0.755013                   3.199047    -8.053167
# 4                   1.302207                   4.311225    -9.445537
#
#    gyr_x_permutation_entropy  gyr_x_spectral_entropy  gyr_x_mean  gyr_x_std  \
# 0                   0.885694                0.700646   -0.122193   0.975336
# 1                   0.888929                0.752013    0.175866   0.997897
# 2                   0.861553                0.674394    0.302432   1.402452
# 3                   0.844317                0.655230   -0.040948   1.322712
# 4                   0.835926                0.743840    0.049576   0.974955
#
#    gyr_x_range  gyr_x_rms  gyr_x_var  gyr_x_min  gyr_x_max  gyr_x_time_energy  \
# 0     7.890398   0.982960   0.951279  -2.854918   5.035480         289.863123
# 1     6.274614   1.013276   0.995799  -1.772905   4.501710         308.018317
# 2     8.283083   1.434690   1.966871  -3.399598   4.883485         617.500693
# 3     8.283083   1.323346   1.749568  -3.399598   4.883485         525.373373
# 4     8.178407   0.976215   0.950537  -4.100139   4.078268         285.898455
#
#    gyr_x_spectral_centroid  gyr_x_spectral_spread  gyr_x_spectral_flatness  \
# 0                 3.674187               3.524650                 0.051321
# 1                 1.965313               3.175495                 0.021709
# 2                 2.585122               3.169252                 0.029460
# 3                 2.172179               2.733406                 0.014597
# 4                 3.046355               2.753534                 0.022062
#
#    gyr_x_peak_frequency_ratio  gyr_x_hjorth_frequency  \
# 0                    0.134129                8.858065
# 1                    0.387727                9.508055
# 2                    0.197661                8.972134
# 3                    0.163654                8.751493
# 4                    0.111199                8.081321
#
#    gyr_x_spectral_skewness  gyr_x_spectral_kurtosis  gyr_x_snr  \
# 0                 1.570359                 5.486321  -8.099291
# 1                 2.370190                 8.403176  -1.984192
# 2                 2.089378                 7.416328  -6.084357
# 3                 2.305314                 8.468150  -7.084601
# 4                 1.969177                 7.826788  -9.027021
#
#    gyr_y_permutation_entropy  gyr_y_spectral_entropy  gyr_y_mean  gyr_y_std  \
# 0                   0.807593                0.644837   -0.077586   1.325038
# 1                   0.796302                0.662586   -0.033233   0.881099
# 2                   0.788056                0.659257   -0.202443   1.007423
# 3                   0.775928                0.618032   -0.115307   0.886364
# 4                   0.755710                0.691552    0.111048   0.779286
#
#    gyr_y_range  gyr_y_rms  gyr_y_var  gyr_y_min  gyr_y_max  gyr_y_time_energy  \
# 0    10.521606   1.327307   1.755725  -5.321257   5.200350         528.523390
# 1     5.532179   0.881725   0.776335  -3.263007   2.269172         233.231835
# 2     5.146535   1.027562   1.014900  -3.263007   1.883529         316.765077
# 3     5.567717   0.893833   0.785641  -2.529474   3.038243         239.681119
# 4     4.967024   0.787159   0.607287  -1.928781   3.038243         185.885661
#
#    gyr_y_spectral_centroid  gyr_y_spectral_spread  gyr_y_spectral_flatness  \
# 0                 2.730635               1.931937                 0.009548
# 1                 3.161118               2.433941                 0.020355
# 2                 2.693794               2.361241                 0.021196
# 3                 2.137342               1.975590                 0.014611
# 4                 2.624221               2.199631                 0.015054
#
#    gyr_y_peak_frequency_ratio  gyr_y_hjorth_frequency  \
# 0                    0.162675                5.972809
# 1                    0.196950                7.295696
# 2                    0.218138                7.144094
# 3                    0.245810                7.125586
# 4                    0.139059                7.492767
#
#    gyr_y_spectral_skewness  gyr_y_spectral_kurtosis  gyr_y_snr  \
# 0                 1.660541                 8.249683  -7.115725
# 1                 2.071150                 9.048734  -6.103869
# 2                 2.079277                10.327007  -5.543993
# 3                 3.214340                18.242780  -4.868815
# 4                 2.488779                10.752487  -7.917757
#
#    gyr_z_permutation_entropy  gyr_z_spectral_entropy  gyr_z_mean  gyr_z_std  \
# 0                   0.836599                0.556364   -0.029741   1.242288
# 1                   0.853208                0.668031    0.071955   0.917765
# 2                   0.815420                0.664368   -0.075330   1.141797
# 3                   0.816256                0.568841   -0.089442   0.898104
# 4                   0.838366                0.695287    0.098991   0.715057
#
#    gyr_z_range  gyr_z_rms  gyr_z_var  gyr_z_min  gyr_z_max  gyr_z_time_energy  \
# 0     9.873076   1.242644   1.543279  -3.991241   5.881834         463.249176
# 1     6.650966   0.920582   0.842293  -2.244887   4.406078         254.241162
# 2     7.623112   1.144280   1.303701  -3.217034   4.406078         392.812807
# 3     5.636445   0.902547   0.806591  -3.217034   2.419411         244.377324
# 4     4.116155   0.721876   0.511306  -1.696744   2.419411         156.331538
#
#    gyr_z_spectral_centroid  gyr_z_spectral_spread  gyr_z_spectral_flatness  \
# 0                 2.195983               1.840313                 0.008620
# 1                 2.402178               2.963912                 0.025910
# 2                 3.178037               3.311781                 0.048595
# 3                 1.927444               2.229758                 0.014286
# 4                 4.025375               3.313482                 0.040365
#
#    gyr_z_peak_frequency_ratio  gyr_z_hjorth_frequency  \
# 0                    0.171723                7.640504
# 1                    0.152693                8.811304
# 2                    0.212650                8.557379
# 3                    0.200791                8.648246
# 4                    0.203372                8.933817
#
#    gyr_z_spectral_skewness  gyr_z_spectral_kurtosis  gyr_z_snr  \
# 0                 3.527473                18.450942  -6.833457
# 1                 2.185009                 7.989944  -7.442231
# 2                 1.818784                 7.211402  -5.685017
# 3                 3.405201                15.967770  -5.999173
# 4                 1.404789                 4.643492  -5.929645
#
#    gyr_mag_permutation_entropy  gyr_mag_spectral_entropy  gyr_mag_mean  \
# 0                     0.884667                  0.697199      1.464268
# 1                     0.902024                  0.705119      1.297907
# 2                     0.885352                  0.739273      1.824945
# 3                     0.884034                  0.695143      1.563644
# 4                     0.896150                  0.740132      1.242264
#
#    gyr_mag_std  gyr_mag_range  gyr_mag_rms  gyr_mag_var  gyr_mag_min  \
# 0     1.458780       7.661882     2.066910     2.128039     0.080930
# 1     0.983400       6.185050     1.628385     0.967075     0.052627
# 2     1.045548       6.185050     2.103234     1.093171     0.052627
# 3     0.959057       5.334091     1.834332     0.919790     0.202737
# 4     0.741957       4.635761     1.446969     0.550500     0.202737
#
#    gyr_mag_max  gyr_mag_time_energy  gyr_mag_spectral_centroid  \
# 0     7.742811          1281.635689                   1.594835
# 1     6.237677           795.491314                   2.288593
# 2     6.237677          1327.078577                   4.385300
# 3     5.536828          1009.431816                   2.211447
# 4     4.838498           628.115655                   2.766208
#
#    gyr_mag_spectral_spread  gyr_mag_spectral_flatness  \
# 0                 2.261422                   0.020200
# 1                 3.317430                   0.060897
# 2                 4.115164                   0.122709
# 3                 3.069521                   0.033359
# 4                 3.066468                   0.052398
#
#    gyr_mag_peak_frequency_ratio  gyr_mag_hjorth_frequency  \
# 0                      0.404471                  7.929673
# 1                      0.251067                 10.619863
# 2                      0.120428                 10.226266
# 3                      0.173301                  9.878856
# 4                      0.180953                 10.534312
#
#    gyr_mag_spectral_skewness  gyr_mag_spectral_kurtosis  gyr_mag_snr
# 0                   2.982728                  18.798298    -1.680163
# 1                   2.850169                  12.926770    -4.746527
# 2                   1.606994                   6.499785    -8.635457
# 3                   2.700893                  10.930407    -6.785468
# 4                   2.701764                  12.984481    -6.557424

# %%
X_train_selected[0:3]
# Out:
# array([[0.05405211, 1.93193747, 5.97280924, 1.84031339, 7.64050376],
#        [0.07808809, 2.43394124, 7.29569606, 2.96391242, 8.81130393],
#        [0.051524  , 2.3612412 , 7.14409358, 3.31178062, 8.55737926]])

# %%
model.fit(X_train_selected, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
generate_accuracy_and_heatmap(model, X_test_selected, y_test)
# Out:
# Accuracy is:  0.41975308641975306
# F1 Score is:  0.40964344650558004
#
#
# Actual     0  1   2
# Predicted
# 0          6  2  13
# 1          3  2   6
# 2          3  2   6
# Classification Report:
#               precision    recall  f1-score   support
#
#     pre-void       0.22      0.37      0.28        46
#         void       0.67      0.45      0.54        94
#    post-void       0.42      0.42      0.42       103
#
#     accuracy                           0.42       243
#    macro avg       0.43      0.41      0.41       243
# weighted avg       0.48      0.42      0.44       243
# 1

# %%
rfe = RFE(estimator=model, step=1)
rfe = rfe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 2
#       1 rfe = RFE(estimator=model, step=1)
# ----> 2 rfe = rfe.fit(X_train, y_train)
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:276, in RFE.fit(self, X, y, **fit_params)
#     273 else:
#     274     routed_params = Bunch(estimator=Bunch(fit=fit_params))
# --> 276 return self._fit(X, y, **routed_params.estimator.fit)
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/sklearn/feature_selection/_rfe.py:334, in RFE._fit(self, X, y, step_score, **fit_params)
#     331 if self.verbose > 0:
#     332     print("Fitting estimator with %d features." % np.sum(support_))
# --> 334 estimator.fit(X[:, features], y, **fit_params)
#     336 # Compute step values on the previous selection iteration because
#     337 # 'estimator' must use features that have not been eliminated yet
#     338 if step_score:
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/xgboost/sklearn.py:1683, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1661 model, metric, params, feature_weights = self._configure_fit(
#    1662     xgb_model, params, feature_weights
#    1663 )
#    1664 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1665     missing=self.missing,
#    1666     X=X,
#    (...)   1680     feature_types=self.feature_types,
#    1681 )
# -> 1683 self._Booster = train(
#    1684     params,
#    1685     train_dmatrix,
#    1686     self.get_num_boosting_rounds(),
#    1687     evals=evals,
#    1688     early_stopping_rounds=self.early_stopping_rounds,
#    1689     evals_result=evals_result,
#    1690     obj=obj,
#    1691     custom_metric=metric,
#    1692     verbose_eval=verbose,
#    1693     xgb_model=model,
#    1694     callbacks=self.callbacks,
#    1695 )
#    1697 if not callable(self.objective):
#    1698     self.objective = params["objective"]
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/xgboost/core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/xgboost/training.py:183, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     181 if cb_container.before_iteration(bst, i, dtrain, evals):
#     182     break
# --> 183 bst.update(dtrain, iteration=i, fobj=obj)
#     184 if cb_container.after_iteration(bst, i, dtrain, evals):
#     185     break
#
# File ~/Public/MPhil_Thesis/Code/wear_uropatch/.venv/lib/python3.12/site-packages/xgboost/core.py:2247, in Booster.update(self, dtrain, iteration, fobj)
#    2243 self._assign_dmatrix_features(dtrain)
#    2245 if fobj is None:
#    2246     _check_call(
# -> 2247         _LIB.XGBoosterUpdateOneIter(
#    2248             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2249         )
#    2250     )
#    2251 else:
#    2252     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
# Ensure full display
pd.set_option("display.max_rows", None)   # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.width", None)    # No wrapping
pd.set_option("display.max_colwidth", None)  # Show long column values

selected_rfe_features = pd.DataFrame({'Feature':list(X_train.columns),
                                    'Ranking':rfe.ranking_})
selected_rfe_features.sort_values(by='Ranking')
# Out:
#                           Feature  Ranking
# 1          acc_x_spectral_entropy        1
# 2                      acc_x_mean        1
# 5                       acc_x_rms        1
# 4                     acc_x_range        1
# 7                       acc_x_min        1
# 13     acc_x_peak_frequency_ratio        1
# 11          acc_x_spectral_spread        1
# 8                       acc_x_max        1
# 14         acc_x_hjorth_frequency        1
# 15        acc_x_spectral_skewness        1
# 12        acc_x_spectral_flatness        1
# 29          acc_y_spectral_spread        1
# 20                     acc_y_mean        1
# 23                      acc_y_rms        1
# 18      acc_y_permutation_entropy        1
# 16        acc_x_spectral_kurtosis        1
# 31     acc_y_peak_frequency_ratio        1
# 30        acc_y_spectral_flatness        1
# 26                      acc_y_max        1
# 25                      acc_y_min        1
# 61                    acc_mag_min        1
# 62                    acc_mag_max        1
# 59                    acc_mag_rms        1
# 44                      acc_z_max        1
# 41                      acc_z_rms        1
# 43                      acc_z_min        1
# 47          acc_z_spectral_spread        1
# 37         acc_z_spectral_entropy        1
# 36      acc_z_permutation_entropy        1
# 34        acc_y_spectral_kurtosis        1
# 33        acc_y_spectral_skewness        1
# 32         acc_y_hjorth_frequency        1
# 56                   acc_mag_mean        1
# 54    acc_mag_permutation_entropy        1
# 55       acc_mag_spectral_entropy        1
# 50         acc_z_hjorth_frequency        1
# 103    gyr_y_peak_frequency_ratio        1
# 109        gyr_z_spectral_entropy        1
# 106       gyr_y_spectral_kurtosis        1
# 104        gyr_y_hjorth_frequency        1
# 111                     gyr_z_std        1
# 108     gyr_z_permutation_entropy        1
# 127      gyr_mag_spectral_entropy        1
# 122        gyr_z_hjorth_frequency        1
# 116                     gyr_z_max        1
# 118       gyr_z_spectral_centroid        1
# 119         gyr_z_spectral_spread        1
# 115                     gyr_z_min        1
# 121    gyr_z_peak_frequency_ratio        1
# 102       gyr_y_spectral_flatness        1
# 86         gyr_x_hjorth_frequency        1
# 91         gyr_y_spectral_entropy        1
# 92                     gyr_y_mean        1
# 88        gyr_x_spectral_kurtosis        1
# 90      gyr_y_permutation_entropy        1
# 93                      gyr_y_std        1
# 72      gyr_x_permutation_entropy        1
# 73         gyr_x_spectral_entropy        1
# 75                      gyr_x_std        1
# 77                      gyr_x_rms        1
# 69      acc_mag_spectral_skewness        1
# 70      acc_mag_spectral_kurtosis        1
# 67   acc_mag_peak_frequency_ratio        1
# 64      acc_mag_spectral_centroid        1
# 100       gyr_y_spectral_centroid        1
# 101         gyr_y_spectral_spread        1
# 97                      gyr_y_min        1
# 139  gyr_mag_peak_frequency_ratio        1
# 136     gyr_mag_spectral_centroid        1
# 137       gyr_mag_spectral_spread        1
# 133                   gyr_mag_min        1
# 129                   gyr_mag_std        1
# 87        gyr_x_spectral_skewness        2
# 40                    acc_z_range        3
# 19         acc_y_spectral_entropy        4
# 21                      acc_y_std        5
# 0       acc_x_permutation_entropy        6
# 123       gyr_z_spectral_skewness        7
# 51        acc_z_spectral_skewness        8
# 141     gyr_mag_spectral_skewness        9
# 39                      acc_z_std       10
# 105       gyr_y_spectral_skewness       11
# 142     gyr_mag_spectral_kurtosis       12
# 38                     acc_z_mean       13
# 120       gyr_z_spectral_flatness       14
# 58                  acc_mag_range       15
# 138     gyr_mag_spectral_flatness       16
# 80                      gyr_x_max       17
# 126   gyr_mag_permutation_entropy       18
# 124       gyr_z_spectral_kurtosis       19
# 85     gyr_x_peak_frequency_ratio       20
# 113                     gyr_z_rms       21
# 79                      gyr_x_min       22
# 84        gyr_x_spectral_flatness       23
# 65        acc_mag_spectral_spread       24
# 98                      gyr_y_max       25
# 76                    gyr_x_range       26
# 3                       acc_x_std       27
# 10        acc_x_spectral_centroid       28
# 46        acc_z_spectral_centroid       29
# 83          gyr_x_spectral_spread       30
# 68       acc_mag_hjorth_frequency       31
# 95                      gyr_y_rms       32
# 82        gyr_x_spectral_centroid       33
# 140      gyr_mag_hjorth_frequency       34
# 49     acc_z_peak_frequency_ratio       35
# 22                    acc_y_range       36
# 66      acc_mag_spectral_flatness       37
# 52        acc_z_spectral_kurtosis       38
# 57                    acc_mag_std       39
# 94                    gyr_y_range       40
# 28        acc_y_spectral_centroid       41
# 74                     gyr_x_mean       42
# 112                   gyr_z_range       43
# 110                    gyr_z_mean       44
# 131                   gyr_mag_rms       45
# 134                   gyr_mag_max       46
# 48        acc_z_spectral_flatness       47
# 78                      gyr_x_var       48
# 89                      gyr_x_snr       49
# 81              gyr_x_time_energy       50
# 128                  gyr_mag_mean       51
# 107                     gyr_y_snr       52
# 96                      gyr_y_var       53
# 99              gyr_y_time_energy       54
# 132                   gyr_mag_var       55
# 130                 gyr_mag_range       56
# 143                   gyr_mag_snr       57
# 135           gyr_mag_time_energy       58
# 125                     gyr_z_snr       59
# 117             gyr_z_time_energy       60
# 114                     gyr_z_var       61
# 45              acc_z_time_energy       62
# 53                      acc_z_snr       63
# 42                      acc_z_var       64
# 71                    acc_mag_snr       65
# 63            acc_mag_time_energy       66
# 60                    acc_mag_var       67
# 24                      acc_y_var       68
# 35                      acc_y_snr       69
# 27              acc_y_time_energy       70
# 17                      acc_x_snr       71
# 9               acc_x_time_energy       72
# 6                       acc_x_var       73

# %%
X_train_rfe = rfe.transform(X_train)
X_test_rfe = rfe.transform(X_test)

# %%
X_train_rfe[0:3]
# Out:
# array([[ 7.27585759e-01,  8.40159411e-01,  5.25261990e+00,
#          1.07943444e+00, -1.10746837e+00,  4.14515153e+00,
#          2.93050307e+00,  5.40521081e-02,  6.31184522e-02,
#          7.89463567e+00,  1.54050171e+00,  8.65194366e+00,
#          8.73659515e-01,  3.27404313e-01,  8.85636510e-01,
#         -2.88871095e+00,  3.10485309e+00,  3.29074145e+00,
#          1.09165754e-01,  8.22348220e-02,  9.54522170e+00,
#          9.72874961e-01,  7.82564817e+00,  8.46072133e-01,
#          7.21074028e-01,  8.84124657e-01, -1.17222843e+00,
#          2.05463065e+00,  3.40737713e+00,  9.12943870e+00,
#          9.14944036e-01,  7.64464750e-01,  1.49193591e+00,
#          1.65263642e+00,  1.35428654e-01,  4.34977566e+00,
#          4.04789954e+00,  1.63802499e-01,  1.91441760e+00,
#          8.07938344e+00,  8.85693546e-01,  7.00645747e-01,
#          9.75335518e-01,  9.82960025e-01,  8.85806548e+00,
#          5.48632143e+00,  8.07592777e-01,  6.44837393e-01,
#         -7.75863408e-02,  1.32503773e+00, -5.32125656e+00,
#          2.73063522e+00,  1.93193747e+00,  9.54842182e-03,
#          1.62675230e-01,  5.97280924e+00,  8.24968301e+00,
#          8.36599134e-01,  5.56364499e-01,  1.24228798e+00,
#         -3.99124133e+00,  5.88183433e+00,  2.19598310e+00,
#          1.84031339e+00,  1.71723456e-01,  7.64050376e+00,
#          6.97199105e-01,  1.45878001e+00,  8.09298319e-02,
#          1.59483469e+00,  2.26142189e+00,  4.04470581e-01],
#        [ 7.31272510e-01,  6.24589018e-01,  5.25664174e+00,
#          8.95808070e-01, -2.27059367e+00,  2.98604808e+00,
#          3.76465495e+00,  7.80880924e-02,  1.24951550e-01,
#          8.43668306e+00,  1.38241703e+00,  5.75201668e+00,
#          8.85486916e-01,  3.72952013e-01,  9.31979620e-01,
#         -2.57739491e+00,  2.85613399e+00,  4.71532089e+00,
#          9.42800545e-02,  1.78022030e-01,  1.00409991e+01,
#          4.69353824e-01,  3.05422291e+00,  8.68693148e-01,
#          7.71123319e-01,  1.02420035e+00, -1.26269230e+00,
#          2.25076038e+00,  2.70405376e+00,  9.18600752e+00,
#          9.30564040e-01,  8.25682570e-01,  1.50617361e+00,
#          1.64925573e+00,  9.97251226e-02,  3.47117480e+00,
#          4.19933168e+00,  2.39274957e-01,  1.21683018e+00,
#          4.22850451e+00,  8.88928823e-01,  7.52012501e-01,
#          9.97897263e-01,  1.01327574e+00,  9.50805472e+00,
#          8.40317623e+00,  7.96301630e-01,  6.62585961e-01,
#         -3.32328694e-02,  8.81098761e-01, -3.26300653e+00,
#          3.16111838e+00,  2.43394124e+00,  2.03554451e-02,
#          1.96949884e-01,  7.29569606e+00,  9.04873403e+00,
#          8.53208186e-01,  6.68031301e-01,  9.17765250e-01,
#         -2.24488744e+00,  4.40607817e+00,  2.40217804e+00,
#          2.96391242e+00,  1.52692587e-01,  8.81130393e+00,
#          7.05118550e-01,  9.83399672e-01,  5.26269359e-02,
#          2.28859269e+00,  3.31743039e+00,  2.51067266e-01],
#        [ 7.39115604e-01,  6.01174924e-01,  5.25664174e+00,
#          9.11407361e-01, -2.27059367e+00,  2.98604808e+00,
#          2.98327829e+00,  5.15239956e-02,  1.19620445e-01,
#          8.62398062e+00,  1.33966782e+00,  7.63555188e+00,
#          8.78755713e-01,  5.76833193e-02,  1.00007019e+00,
#         -2.58010353e+00,  2.85613399e+00,  4.22234242e+00,
#          1.14430791e-01,  1.21467970e-01,  9.83614725e+00,
#          6.28711510e-01,  3.81494338e+00,  8.46271579e-01,
#          7.59722970e-01,  9.08485686e-01, -1.54471754e+00,
#          2.25076038e+00,  3.34923576e+00,  9.04968470e+00,
#          9.47760890e-01,  8.33700218e-01,  1.48295728e+00,
#          1.62976993e+00,  9.97251226e-02,  3.47117480e+00,
#          6.16353391e+00,  5.95324980e-02,  1.64958765e+00,
#          6.08158105e+00,  8.61552585e-01,  6.74394043e-01,
#          1.40245161e+00,  1.43469009e+00,  8.97213426e+00,
#          7.41632758e+00,  7.88055709e-01,  6.59256962e-01,
#         -2.02443076e-01,  1.00742265e+00, -3.26300653e+00,
#          2.69379393e+00,  2.36124120e+00,  2.11962004e-02,
#          2.18137785e-01,  7.14409358e+00,  1.03270067e+01,
#          8.15419859e-01,  6.64367556e-01,  1.14179745e+00,
#         -3.21703382e+00,  4.40607817e+00,  3.17803683e+00,
#          3.31178062e+00,  2.12650285e-01,  8.55737926e+00,
#          7.39273078e-01,  1.04554839e+00,  5.26269359e-02,
#          4.38530045e+00,  4.11516430e+00,  1.20427574e-01]])

# %%
model_rfe = model.fit(X_train_rfe, y_train)

# %%
generate_accuracy_and_heatmap(model_rfe, X_test_rfe, y_test)
# Out:
# Accuracy is:  0.6831275720164609
# F1 Score is:  0.42962962962962964
#
#
# Actual      0   1
# Predicted
# 0          14  20
# 1           4   5
# Classification Report:
#               precision    recall  f1-score   support
#
#         void       0.71      0.31      0.43        94
#     non-void       0.68      0.92      0.78       149
#
#     accuracy                           0.68       243
#    macro avg       0.69      0.61      0.61       243
# weighted avg       0.69      0.68      0.64       243
# 1

# %%
# rfecv = RFECV(estimator=model, step=1, cv=5, scoring='accuracy')
# rfecv = rfecv.fit(X_train, y_train)
# print('Optimal number of features :', rfecv.n_features_)
# print('Best features :', X_train.columns[rfecv.support_])

# %%
# # Correct attributes:
# print("Optimal number of features:", rfecv.n_features_)
# # print("Cross-validation scores:", rfecv.cv_results_['mean_test_score'])
# # print("Selected features:", rfecv.support_)
# # print("Feature rankings:", rfecv.ranking_)

# %%
# # This gives you the mean CV score for each number of features tested
# cv_scores = rfecv.cv_results_['mean_test_score']
# # print("CV scores:", cv_scores)

# # Plot the scores
# import matplotlib.pyplot as plt
# plt.figure(figsize=(10, 6))
# plt.plot(range(1, len(cv_scores) + 1), cv_scores, marker='o')
# plt.xlabel('Number of Features')
# plt.ylabel('Cross-Validation Score')
# plt.title('RFECV Performance vs Number of Features')
# plt.grid(True)
# plt.show()

# %%
# X_train_rfecv = rfecv.transform(X_train)
# X_test_rfecv = rfecv.transform(X_test)

# %%
# model_rfecv = model.fit(X_train_rfecv, y_train)

# %%
# generate_accuracy_and_heatmap(model_rfecv, X_test_rfecv, y_test)

# %%
# plt.figure()
# plt.xlabel("Number of features selected")
# plt.ylabel("Cross validation score of number of selected features")
# plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
# plt.show()
