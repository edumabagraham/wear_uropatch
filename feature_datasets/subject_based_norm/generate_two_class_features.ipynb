# %% [markdown]
# ## Generate feature extracted data based on window size, overlap and class numbers.
# 1. Extract features with two class labels

# %%
import sys
sys.path.append('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch')
import os
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from essentials import two_class_labels, normalize
from feature_set_4 import GenerateFeatures 
import copy

# %%
with open('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/data/df_dict_imu.pkl', 'rb') as f:
    imu_dict = pickle.load(f)
with open('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/data/df_minze_dict.pkl', 'rb') as f:
    ground_truth_dict = pickle.load(f)
with open('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/data/df_dict_urineestimate_method1.pkl', 'rb') as f:
    urine_estimate_dict = pickle.load(f)

# %% [markdown]
# Remove the data with the almost the entire data being void.
# 1. subj_9_void4
# 2. subj_11_void2

# %%
del imu_dict['subj_9_void4']
del imu_dict['subj_11_void2']

# %% [markdown]
# Extract windowed features from the 3 axis of the accelerometer and the acceleration magnitude.
# 1. mean
# 2. rms
# 3. std
# 4. range
# 5. variance
# 6. min
# 7. max
# 8. time energy
# 9. spectral energy
# 10. permutation entropy
# 11. spectral entropy

# %% [markdown]
# ## Two class data

# %% [markdown]
# ## Data 1
# classes: void, non-void
#
# fs: original
#
# sliding window: 1s
#
# overlap: 0
#
# filename: two_class_raw_1s_no.csv

# %%
labelled_imu_dict = {}
dict = copy.deepcopy(imu_dict)
for i_void_instance, void_instance in tqdm(enumerate(dict.keys()), desc="Adding labels to IMU data"):
    acc = dict[void_instance]
    gt = ground_truth_dict[void_instance]
    
    # normalize data
    df = normalize(acc)
    
    # add the labels
    labelled_df = two_class_labels(df, gt)
    
    labelled_imu_dict[void_instance] = labelled_df
# Out:
# Adding labels to IMU data: 41it [00:00, 300.79it/s]

# %%
#  do not upsample
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=1.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 31.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.69it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.00it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.53it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.94it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.89it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.03it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.74it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.99it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 36.10it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.38it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.58it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.71it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.68it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.29it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.38it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.30it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.93it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.11it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.18it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.85it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.13it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_1s_no.csv', index=False)
final_features.head()
# Out:
#    center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0     0.499593    0.938842   1.134729      2.169033   27.488924
# 1     1.498779    1.115575   0.848165      1.963893   21.061566
# 2     2.497964    0.804784   0.245606      0.707999    9.214712
# 3     3.497150    0.720945   0.292908      0.605557    9.463613
# 4     4.496336    0.588285   0.231525      0.399683   10.304930
#
#    acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0             0.912208            0.016935              0.955511
# 1             0.935280            0.016935              0.771109
# 2             0.964494            0.016935              1.791759
# 3             0.951214            0.016935              1.236763
# 4             0.936266            0.016935              1.845827
#
#    acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                  5.004075                 5.012356  ...
# 1                  2.001630                 3.190464  ...
# 2                  2.001630                 6.507641  ...
# 3                  6.004890                 7.154587  ...
# 4                  6.004890                 8.345464  ...
#
#    gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                 0.298711     0.037201    -0.056033     0.539271
# 1                 0.081451     0.237416    -0.180868     0.769078
# 2                 0.018886    -0.237806     0.203240     0.323739
# 3                 0.024478    -0.135918    -0.089793     0.590726
# 4                 0.029350     0.087680     0.026996     0.639205
#
#    acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0      0.249948  0.133549            1.747646            2.784556  non-void
# 1      0.217836  0.133930            1.545172            2.320707  non-void
# 2     -0.062160  0.021656            1.154535            0.494648  non-void
# 3      0.116232  0.042694            1.083606            0.871746  non-void
# 4     -0.156176  0.031684            1.923561            0.862959  non-void
#
#    experiment_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Data 1b
# classes: void, non-void
#
# fs: original
#
# sliding window: 1s
#
# overlap: 0.5
#
# filename: two_class_raw_1s_yo_0.5.csv

# %%
#  do not upsample
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=1.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.46it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.92it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.33it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.15it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.44it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.03it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.82it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.18it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.55it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.79it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.10it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.63it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.04it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.62it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.77it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.80it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.80it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.26it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.56it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.65it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.28it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.19it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_1s_0.5.csv', index=False)
final_features.head()
# Out:
#    center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0     0.499593    0.938842   1.134729      2.169033   27.488924
# 1     1.007653    1.222071   1.215933      2.971949   32.460712
# 2     1.515714    1.124070   0.841010      1.970831   19.248690
# 3     2.023774    0.736422   0.308414      0.637436   10.164232
# 4     2.531835    0.819740   0.250344      0.734645    9.837690
#
#    acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0             0.912208            0.016935              0.955511
# 1             0.920026            0.016935              1.526056
# 2             0.933417            0.016935              0.756863
# 3             0.945890            0.016935              1.236763
# 4             0.942672            0.016935              1.722767
#
#    acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                  5.004075                 5.012356  ...
# 1                  6.004890                 5.080763  ...
# 2                  2.001630                 3.111095  ...
# 3                  7.005705                 7.069571  ...
# 4                  2.001630                 6.174513  ...
#
#    gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                 0.298711     0.037201    -0.056033     0.539271
# 1                 0.326431     0.191498    -0.018243     0.717867
# 2                 0.067443     0.191622    -0.252056     0.729552
# 3                 0.011282    -0.194969     0.036613     0.251210
# 4                 0.018613    -0.248196     0.129861     0.319838
#
#    acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0      0.249948  0.133549            1.747646            2.784556  non-void
# 1      0.145490  0.131027            1.896573            2.963738  non-void
# 2      0.189556  0.124463            1.514512            2.222696  non-void
# 3     -0.230262  0.060939            1.089863            0.836561  non-void
# 4     -0.075508  0.023182            1.166303            0.510228  non-void
#
#    experiment_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Data 1c
# classes: void, non-void
#
# fs: original
#
# sliding window: 1s
#
# overlap: 0.8
#
# filename: two_class_raw_1s_yo_0.8.csv

# %%
#  do not upsample
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=1.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.81it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.46it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.21it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.87it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  2.81it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.56it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:02<00:00,  2.45it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  2.93it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.63it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.94it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.15it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.94it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:02<00:00,  2.48it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.33it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.79it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.47it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  2.83it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.74it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  2.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.60it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:02<00:00,  1.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.74it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.53it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.68it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.85it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.44it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:04<00:00,  1.21it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.69it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_1s_0.8.csv', index=False)
final_features.head()
# Out:
#    center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0     0.499593    0.938842   1.134729      2.169033   27.488924
# 1     0.702817    0.983020   1.152208      2.293911   30.398463
# 2     0.906041    1.225253   1.212918      2.972414   32.325434
# 3     1.109266    1.268793   1.182149      3.007312   30.433342
# 4     1.312490    1.142122   1.200226      2.744983   27.668439
#
#    acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0             0.912208            0.016935              0.955511
# 1             0.884909            0.016935              1.170071
# 2             0.886697            0.016935              1.021651
# 3             0.922150            0.016935              1.170071
# 4             0.895832            0.016935              0.659246
#
#    acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                  5.004075                 5.012356  ...
# 1                  5.004075                 4.658724  ...
# 2                  5.004075                 4.823689  ...
# 3                  6.004890                 5.329942  ...
# 4                  6.004890                 4.437748  ...
#
#    gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                 0.298711     0.037201    -0.056033     0.539271
# 1                 0.179452     0.293840     0.101216     0.667022
# 2                 0.329331     0.211464     0.019451     0.741511
# 3                 0.317698     0.244637    -0.020904     0.709575
# 4                 0.266304     0.346269    -0.040062     0.719099
#
#    acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0      0.249948  0.133549            1.747646            2.784556  non-void
# 1      0.371200  0.144950            1.737057            2.965490  non-void
# 2      0.232239  0.140417            1.936316            3.099060  non-void
# 3      0.094679  0.153499            1.900757            3.043200  non-void
# 4      0.242046  0.169619            1.736450            2.873066  non-void
#
#    experiment_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Data 2
# classes: void, non-void
#
# fs: original
#
# overlap: 0
#
# sliding window: 2s
#
# filename: two_class_raw_2s_no.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=2.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 36.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 55.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 59.11it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 48.56it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.44it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 31.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 40.82it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 66.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 52.94it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 48.93it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.49it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 59.40it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 59.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 57.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.60it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.83it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 31.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.58it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 57.31it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 42.81it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 40.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 69.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.44it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.15it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 31.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.33it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 55.22it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.81it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 49.05it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_2s_no.csv', index=False)
final_features.head()
# Out:
#    center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0     0.999186    1.027208   1.005637      2.066463   24.702545
# 1     2.997557    0.762864   0.273525      0.656778    9.516582
# 2     4.995929    0.381709   0.479763      0.375875   12.122137
# 3     6.994300    0.842092   0.846989      1.426509   22.014882
# 4     8.992671    0.565058   0.443517      0.515997   14.184323
#
#    acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0             0.922460            0.016935              0.758286
# 1             0.962838            0.016935              1.414307
# 2             0.833639            0.016935              1.396447
# 3             0.888897            0.016935              1.076139
# 4             0.899162            0.016935              1.402126
#
#    acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                  5.504482                 4.866430  ...
# 1                  7.005705                 7.133455  ...
# 2                  0.500407                 4.853211  ...
# 3                  6.004890                 4.992569  ...
# 4                  7.005705                 6.824539  ...
#
#    gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                 0.433022     0.113884    -0.069472     0.617961
# 1                 0.031394    -0.167799     0.012058     0.459326
# 2                 0.051982    -0.058582    -0.204570     0.700326
# 3                 0.251759    -0.065512     0.036206     0.701680
# 4                 0.154371    -0.068425     0.226174     0.651821
#
#    acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0      0.241386  0.161761            1.646409            2.552632  non-void
# 1      0.009044  0.032951            1.119071            0.683197  non-void
# 2     -0.094720  0.080964            1.800085            1.421490  non-void
# 3      0.160792  0.158051            1.529054            1.713838  non-void
# 4      0.276912  0.377185            1.383269            1.847173  non-void
#
#    experiment_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Data 2b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 2s
#
# filename: two_class_raw_2s_yo_0.5.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=2.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.26it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.00it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.49it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.30it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.48it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.03it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.71it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.15it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.68it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.85it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.48it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.43it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.80it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.10it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.74it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.48it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.99it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.34it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.71it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.46it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.43it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 25.56it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.29it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 25.52it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_2s_0.5.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        0.999186    1.027208   1.005637      2.066463   24.702545
# 1        1.998371    0.960179   0.643429      1.335946   15.046835
# 2        2.997557    0.762864   0.273525      0.656778    9.516582
# 3        3.996743    0.654615   0.272212      0.502620    9.864408
# 4        4.995929    0.381709   0.479763      0.375875   12.122137
# ...           ...         ...        ...           ...         ...
# 2361    35.741867   -0.476250   0.133958      0.244759    3.323721
# 2362    36.734466   -0.541521   0.077004      0.299175    2.929258
# 2363    37.727066   -0.397643   0.156814      0.182711    3.105101
# 2364    38.719666   -0.257434   0.088402      0.074087    3.196974
# 2365    39.712266   -0.293096   0.105920      0.097124    3.123580
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.922460            0.016935              0.758286
# 1                0.946091            0.016935              0.846495
# 2                0.962838            0.016935              1.414307
# 3                0.945347            0.016935              1.296888
# 4                0.833639            0.016935              1.396447
# ...                   ...                 ...                   ...
# 2361             0.982164            0.016543              1.408767
# 2362             0.986050            0.016543              1.328536
# 2363             0.976195            0.016543              0.886829
# 2364             0.953721            0.016543              1.629241
# 2365             0.961010            0.016543              1.279049
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.504482                 4.866430  ...
# 1                     2.502037                 4.024960  ...
# 2                     7.005705                 7.133455  ...
# 3                     5.504482                 6.614445  ...
# 4                     0.500407                 4.853211  ...
# ...                        ...                      ...  ...
# 2361                  0.499565                 7.531672  ...
# 2362                  0.499565                 9.639247  ...
# 2363                  0.499565                 3.303041  ...
# 2364                  0.499565                 7.561225  ...
# 2365                  1.498694                 4.981332  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.433022     0.113884    -0.069472     0.617961
# 1                    0.026769     0.134115    -0.190618     0.687476
# 2                    0.031394    -0.167799     0.012058     0.459326
# 3                    0.121658    -0.149286    -0.216850     0.734273
# 4                    0.051982    -0.058582    -0.204570     0.700326
# ...                       ...          ...          ...          ...
# 2361                 0.044109    -0.170184    -0.224131     0.876744
# 2362                 0.051710     0.181962     0.265529     0.936136
# 2363                 0.110439    -0.152894    -0.178006     0.893149
# 2364                 0.050135    -0.188200    -0.169465     0.846853
# 2365                 0.047461     0.025255     0.029395     0.865425
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.241386  0.161761            1.646409            2.552632
# 1         0.326583  0.081498            1.349853            1.407678
# 2         0.009044  0.032951            1.119071            0.683197
# 3        -0.017657  0.067167            1.503584            0.867352
# 4        -0.094720  0.080964            1.800085            1.421490
# ...            ...       ...                 ...                 ...
# 2361     -0.638962  0.018042            0.626773            0.833723
# 2362      0.124743  0.010973            0.770362            0.706243
# 2363      0.214224  0.013437            0.741940            0.816687
# 2364      0.186413  0.008558            0.653247            0.711023
# 2365     -0.047159  0.009663            0.689296            0.752265
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 2361  non-void             41
# 2362  non-void             41
# 2363  non-void             41
# 2364  non-void             41
# 2365  non-void             41
#
# [2366 rows x 85 columns]

# %% [markdown]
# ## Data 2c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 2s
#
# filename: two_class_raw_2s_yo_0.8.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=2.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.31it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.92it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.47it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.30it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.79it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.60it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  4.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.17it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.93it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.31it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.32it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.62it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.70it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.19it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.58it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.28it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.32it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.28it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.69it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:02<00:00,  2.17it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.39it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_2s_0.8.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        0.999186    1.027208   1.005637      2.066463   24.702545
# 1        1.405634    1.034451   0.929655      1.934348   21.458067
# 2        1.812083    0.978279   0.880376      1.732091   18.060970
# 3        2.218531    0.898469   0.559360      1.120130   12.050941
# 4        2.624979    0.776798   0.255682      0.668788    8.368345
# ...           ...         ...        ...           ...         ...
# 5822    38.322626   -0.303416   0.131681      0.109401    3.107525
# 5823    38.719666   -0.257434   0.088402      0.074087    3.196974
# 5824    39.116706   -0.250697   0.092173      0.071345    3.111349
# 5825    39.513746   -0.275963   0.094892      0.085160    2.936977
# 5826    39.910786   -0.318816   0.118315      0.115642    3.195623
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.922460            0.016935              0.758286
# 1                0.921858            0.016935              0.712692
# 2                0.912551            0.016935              0.633043
# 3                0.951162            0.016935              0.943690
# 4                0.970977            0.016935              1.342674
# ...                   ...                 ...                   ...
# 5822             0.962683            0.016543              1.060391
# 5823             0.953721            0.016543              1.629241
# 5824             0.947917            0.016543              1.580450
# 5825             0.963100            0.016543              1.329724
# 5826             0.958392            0.016543              1.311534
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.504482                 4.866430  ...
# 1                     5.504482                 4.274918  ...
# 2                     2.502037                 3.496527  ...
# 3                     6.505297                 5.905786  ...
# 4                     7.005705                 6.944119  ...
# ...                        ...                      ...  ...
# 5822                  0.499565                 3.954413  ...
# 5823                  0.499565                 7.561225  ...
# 5824                  8.492598                 9.503543  ...
# 5825                  1.498694                 7.063329  ...
# 5826                  1.498694                 3.955229  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.433022     0.113884    -0.069472     0.617961
# 1                    0.282971     0.167962    -0.102216     0.644390
# 2                    0.059930     0.250826    -0.092330     0.657934
# 3                    0.025770    -0.165077    -0.474689     0.603798
# 4                    0.027550    -0.185088     0.071125     0.440630
# ...                       ...          ...          ...          ...
# 5822                 0.051882    -0.346402    -0.379857     0.879745
# 5823                 0.050135    -0.188200    -0.169465     0.846853
# 5824                 0.044763    -0.131523    -0.081729     0.858617
# 5825                 0.045301    -0.032944     0.025586     0.865877
# 5826                 0.049460    -0.008584    -0.042294     0.885365
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.241386  0.161761            1.646409            2.552632
# 1         0.395383  0.161737            1.535310            2.119416
# 2         0.395574  0.114310            1.451056            1.686827
# 3         0.185676  0.074821            1.252705            1.165425
# 4        -0.019086  0.030820            1.090282            0.542118
# ...            ...       ...                 ...                 ...
# 5822      0.341358  0.010471            0.687180            0.814189
# 5823      0.186413  0.008558            0.653247            0.711023
# 5824     -0.051659  0.009450            0.636059            0.649435
# 5825     -0.141871  0.009938            0.667276            0.694077
# 5826     -0.071430  0.009096            0.716563            0.767270
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 5822  non-void             41
# 5823  non-void             41
# 5824  non-void             41
# 5825  non-void             41
# 5826  non-void             41
#
# [5827 rows x 85 columns]

# %% [markdown]
# ## Data 3
# classes: void, non-void
#
# fs: original
#
# overlap: 0
#
# sliding window: 3s
#
# filename: two_class_raw_3s_no.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=3.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 54.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 72.30it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.38it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 76.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 37.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 59.83it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 64.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.63it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 43.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.04it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.45it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 55.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.83it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 90.56it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 68.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 69.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.19it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 77.63it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 78.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 74.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 33.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 56.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 46.63it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.24it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 37.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.87it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 59.71it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 76.95it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 58.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 86.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 60.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 74.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 42.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 48.31it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 42.16it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 63.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 70.55it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.47it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 70.02it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_3s_no.csv', index=False)
final_features.head()
# Out:
#    center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0     1.498779    0.953067   0.839825      1.613642   19.483560
# 1     4.496336    0.494788   0.455654      0.452436   11.220113
# 2     7.493893    0.758589   0.711104      1.081126   17.810583
# 3    10.491450    0.635391   0.492101      0.645885   14.363947
# 4    13.489007    0.386718   0.475147      0.375315   12.953937
#
#    acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0             0.930302            0.016935              0.732464
# 1             0.886151            0.016935              1.195315
# 2             0.896869            0.016935              0.965959
# 3             0.920285            0.016935              1.425515
# 4             0.872672            0.016935              1.260717
#
#    acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                  5.535758                 4.757182  ...
# 1                  5.535758                 6.768689  ...
# 2                  5.997071                 4.963067  ...
# 3                  0.922626                 4.259788  ...
# 4                  2.767879                 5.953986  ...
#
#    gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                 0.406946     0.076387    -0.096975     0.600847
# 1                 0.114098    -0.175302    -0.361143     0.704438
# 2                 0.247453    -0.084767    -0.085036     0.646938
# 3                 0.183335     0.026091     0.270384     0.583386
# 4                 0.277723     0.047597     0.282095     0.592904
#
#    acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0      0.349407  0.133637            1.482451            1.866637  non-void
# 1      0.080459  0.094265            1.561259            1.238242  non-void
# 2      0.133341  0.308302            1.479014            1.671782  non-void
# 3      0.296998  0.263869            1.314198            1.602418  non-void
# 4      0.424169  0.160867            1.144205            1.186102  non-void
#
#    experiment_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#
# [5 rows x 85 columns]

# %% [markdown]
# ## Data 3b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 3s
#
# filename: two_class_raw_3s_yo_0.5.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=3.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 37.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.24it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 25.47it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.33it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.62it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.03it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.77it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.24it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.15it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.15it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.70it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 36.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.45it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.49it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.19it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.95it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 38.94it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 45.60it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 37.38it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.17it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.54it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 33.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 39.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.28it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.65it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_3s_0.5.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        1.498779    0.953067   0.839825      1.613642   19.483560
# 1        2.989089    0.731636   0.286953      0.617634    9.518142
# 2        4.479400    0.483426   0.432560      0.420808   11.130985
# 3        5.969711    0.548849   0.809403      0.956368   19.209790
# 4        7.460022    0.776208   0.723594      1.126086   18.111692
# ...           ...         ...        ...           ...         ...
# 1555    32.764067    0.617709   0.389886      0.533575    4.084924
# 1556    34.252967    0.295937   0.552217      0.392523    3.639527
# 1557    35.741867   -0.366768   0.314805      0.233621    3.311919
# 1558    37.230766   -0.449663   0.154201      0.225975    3.050020
# 1559    38.719666   -0.311562   0.131272      0.114303    2.990635
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.930302            0.016935              0.732464
# 1                0.959767            0.016935              1.411828
# 2                0.905194            0.016935              1.201422
# 3                0.896639            0.016935              1.176905
# 4                0.915078            0.016935              0.952506
# ...                   ...                 ...                   ...
# 1555             0.988921            0.016543              0.517922
# 1556             0.985763            0.016543              0.354412
# 1557             0.980933            0.016543              0.544643
# 1558             0.983733            0.016543              0.885965
# 1559             0.965449            0.016543              1.226174
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.535758                 4.757182  ...
# 1                     6.919697                 6.960362  ...
# 2                     5.535758                 6.759804  ...
# 3                     0.922626                 3.003914  ...
# 4                     5.997071                 4.965532  ...
# ...                        ...                      ...  ...
# 1555                  0.472245                 1.375220  ...
# 1556                  0.472245                 1.929761  ...
# 1557                  0.472245                 1.859945  ...
# 1558                  0.472245                 8.890633  ...
# 1559                  0.472245                 3.569590  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.406946     0.076387    -0.096975     0.600847
# 1                    0.029453    -0.108568    -0.084068     0.552839
# 2                    0.114253    -0.105224    -0.295491     0.677153
# 3                    0.129794    -0.171039    -0.257879     0.679567
# 4                    0.254077    -0.108291    -0.105016     0.655747
# ...                       ...          ...          ...          ...
# 1555                 0.044278     0.353457     0.282356     0.892929
# 1556                 0.106457    -0.105673    -0.323662     0.830298
# 1557                 0.064799    -0.560601    -0.647829     0.897463
# 1558                 0.058613     0.129760     0.162830     0.912583
# 1559                 0.060439    -0.239772    -0.246174     0.879264
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.349407  0.133637            1.482451            1.866637
# 1        -0.018445  0.058893            1.185820            0.833215
# 2         0.052231  0.087352            1.548907            1.222331
# 3        -0.003780  0.418064            1.697595            1.640069
# 4         0.167473  0.299263            1.497533            1.700828
# ...            ...       ...                 ...                 ...
# 1555     -0.726541  0.048416            0.746150            1.589861
# 1556     -0.544078  0.067406            0.662218            1.276728
# 1557     -0.716729  0.046063            0.615118            1.043572
# 1558      0.199245  0.020227            0.728769            0.729865
# 1559      0.225597  0.010800            0.691408            0.788449
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 1555  non-void             41
# 1556  non-void             41
# 1557  non-void             41
# 1558  non-void             41
# 1559  non-void             41
#
# [1560 rows x 85 columns]

# %% [markdown]
# ## Data 3c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 3s
#
# filename: two_class_raw_3s_yo_0.8.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=3.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.04it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.10it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.17it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.19it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.53it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.21it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.24it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.17it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.38it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.04it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.68it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  6.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.34it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.03it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.00it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.74it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.79it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.93it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.83it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.83it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.46it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.59it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  2.88it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.11it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_3s_0.8.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        1.498779    0.953067   0.839825      1.613642   19.483560
# 1        2.091516    0.937189   0.752365      1.444375   16.064913
# 2        2.684253    0.836695   0.516392      0.966720   11.176730
# 3        3.276990    0.724808   0.273863      0.600348    9.715540
# 4        3.869728    0.654555   0.289030      0.511981    9.715650
# ...           ...         ...        ...           ...         ...
# 3885    37.230766   -0.449663   0.154201      0.225975    3.050020
# 3886    37.826326   -0.389008   0.166484      0.179044    2.981789
# 3887    38.421886   -0.325674   0.148317      0.128061    3.173577
# 3888    39.017446   -0.289582   0.108687      0.095670    2.996432
# 3889    39.613006   -0.306766   0.127977      0.110483    3.166705
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.930302            0.016935              0.732464
# 1                0.939576            0.016935              0.701166
# 2                0.951540            0.016935              0.922687
# 3                0.955237            0.016935              1.440708
# 4                0.954451            0.016935              1.335001
# ...                   ...                 ...                   ...
# 3885             0.983733            0.016543              0.885965
# 3886             0.977980            0.016543              0.898322
# 3887             0.969200            0.016543              1.050550
# 3888             0.963300            0.016543              1.398357
# 3889             0.966248            0.016543              1.231613
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.535758                 4.757182  ...
# 1                     5.997071                 3.735016  ...
# 2                     6.919697                 5.660981  ...
# 3                     6.919697                 7.091568  ...
# 4                     5.997071                 6.592176  ...
# ...                        ...                      ...  ...
# 3885                  0.472245                 8.890633  ...
# 3886                  0.472245                 4.216030  ...
# 3887                  0.472245                 3.165288  ...
# 3888                  0.472245                 5.069573  ...
# 3889                  8.500404                 9.190738  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.406946     0.076387    -0.096975     0.600847
# 1                    0.124434     0.107435    -0.173207     0.632793
# 2                    0.027751    -0.080806    -0.370532     0.613729
# 3                    0.030325    -0.182683    -0.202423     0.645939
# 4                    0.064735    -0.076608    -0.258715     0.694073
# ...                       ...          ...          ...          ...
# 3885                 0.058613     0.129760     0.162830     0.912583
# 3886                 0.095991     0.012482     0.040458     0.893438
# 3887                 0.095572    -0.221048    -0.263422     0.879072
# 3888                 0.051392    -0.233781    -0.252719     0.871507
# 3889                 0.048134    -0.169773    -0.209579     0.871925
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.349407  0.133637            1.482451            1.866637
# 1         0.439577  0.124356            1.360390            1.394412
# 2         0.224472  0.073114            1.227840            1.099562
# 3         0.053046  0.055527            1.318302            0.710148
# 4         0.105261  0.067007            1.454805            0.810148
# ...            ...       ...                 ...                 ...
# 3885      0.199245  0.020227            0.728769            0.729865
# 3886      0.178505  0.019224            0.716762            0.719302
# 3887      0.147624  0.011936            0.705305            0.771008
# 3888      0.283301  0.008837            0.683820            0.809710
# 3889     -0.019278  0.010172            0.688969            0.692914
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 3885  non-void             41
# 3886  non-void             41
# 3887  non-void             41
# 3888  non-void             41
# 3889  non-void             41
#
# [3890 rows x 85 columns]

# %% [markdown]
# ## Data 4
# classes: void, non-void
#
# fs: original
#
# overlap: 0.0
#
# sliding window: 4s
#
# filename: two_class_raw_4s_no.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=4.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 62.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 84.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 91.10it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 71.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 80.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 42.62it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.26it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.97it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 42.31it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 65.45it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.47it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 111.88it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 88.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 81.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.88it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 99.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 97.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 87.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 66.44it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 55.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 39.53it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 51.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 70.00it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 84.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 66.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 66.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 109.75it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 70.65it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 88.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 52.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 57.48it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 80.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 88.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 69.93it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_4s_no.csv', index=False)
final_features
# Out:
#      center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0       1.998371    0.895036   0.748686      1.361620   17.055717
# 1       5.995114    0.611901   0.725789      0.901192   17.138390
# 2       9.991857    0.624439   0.438269      0.582004   13.035493
# 3      13.988600    0.295423   0.460685      0.299506   12.222025
# 4      17.985343    0.394139   1.000649      1.156644   11.038946
# ..           ...         ...        ...           ...         ...
# 578    22.019174    0.580965   0.140694      0.357315    3.284957
# 579    26.022660    0.662380   0.124837      0.454331    3.867538
# 580    30.026146    0.501795   0.416167      0.424994    4.242243
# 581    34.029632    0.336264   0.569845      0.437797    3.629799
# 582    38.033118   -0.381130   0.166242      0.172896    3.067513
#
#      acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0               0.933704            0.016935              0.721129
# 1               0.910789            0.016935              1.166932
# 2               0.926953            0.016935              1.325225
# 3               0.860789            0.016935              1.240564
# 4               0.965989            0.016935              0.531641
# ..                   ...                 ...                   ...
# 578             0.985768            0.016543              1.091516
# 579             0.985636            0.016543              1.384769
# 580             0.981126            0.016543              0.483491
# 581             0.988654            0.016543              0.347153
# 582             0.978070            0.016543              0.946724
#
#      acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                    5.535758                 4.783760  ...
# 1                    2.306566                 3.765380  ...
# 2                    0.922626                 5.394173  ...
# 3                    5.997071                 5.580798  ...
# 4                    0.461313                 7.017798  ...
# ..                        ...                      ...  ...
# 578                  0.472245                 6.945493  ...
# 579                  0.472245                 6.132933  ...
# 580                  0.472245                 1.934547  ...
# 581                  0.472245                 2.183934  ...
# 582                  0.472245                 4.767357  ...
#
#      gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                   0.216851     0.057595    -0.123856     0.594318
# 1                   0.177183    -0.193035    -0.285993     0.714811
# 2                   0.173703     0.009580     0.169398     0.605772
# 3                   0.163644     0.021715     0.255598     0.625402
# 4                   0.091636    -0.216172    -0.290915     0.638848
# ..                       ...          ...          ...          ...
# 578                 0.098274     0.426761     0.426853     0.897468
# 579                 0.060261     0.275066     0.271008     0.948491
# 580                 0.087974    -0.391642    -0.562127     0.912561
# 581                 0.085143    -0.187551    -0.418936     0.842823
# 582                 0.073968     0.111211     0.153465     0.895868
#
#      acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0        0.382591  0.122478            1.382740            1.617914  non-void
# 1       -0.011644  0.449817            1.664570            1.567664  non-void
# 2        0.258683  0.365241            1.330382            1.598731  non-void
# 3        0.368199  0.168923            1.133725            1.170979  non-void
# 4        0.478585  0.115481            1.548812            1.440376      void
# ..            ...       ...                 ...                 ...       ...
# 578     -0.142547  0.001265            1.901990            0.790107      void
# 579      0.373640  0.014303            1.105698            0.930813      void
# 580     -0.494243  0.091467            0.719994            1.765990  non-void
# 581     -0.494132  0.064215            0.696150            1.183135  non-void
# 582      0.122951  0.020529            0.713392            0.725106  non-void
#
#      experiment_id
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 578             41
# 579             41
# 580             41
# 581             41
# 582             41
#
# [583 rows x 85 columns]

# %% [markdown]
# ## Data 4b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 4s
#
# filename: two_class_raw_4s_yo_0.5.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=4.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 46.82it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 26.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.70it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 35.93it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 40.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.59it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.97it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.24it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 59.69it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 46.49it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 51.21it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.58it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.77it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.33it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.59it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.89it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 38.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 34.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 58.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 36.68it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.09it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 25.49it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 40.11it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 48.70it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.66it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_4s_0.5.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        1.998371    0.895036   0.748686      1.361620   17.055717
# 1        3.996743    0.572287   0.434528      0.516326   10.805491
# 2        5.995114    0.611901   0.725789      0.901192   17.138390
# 3        7.993486    0.703575   0.690098      0.971253   18.126929
# 4        9.991857    0.624439   0.438269      0.582004   13.035493
# ...           ...         ...        ...           ...         ...
# 1143    30.026146    0.501795   0.416167      0.424994    4.242243
# 1144    32.027889    0.501798   0.412469      0.421932    4.192192
# 1145    34.029632    0.336264   0.569845      0.437797    3.629799
# 1146    36.031375   -0.331151   0.355019      0.235700    3.238999
# 1147    38.033118   -0.381130   0.166242      0.172896    3.067513
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.933704            0.016935              0.721129
# 1                0.915848            0.016935              1.193320
# 2                0.910789            0.016935              1.166932
# 3                0.892343            0.016935              1.094785
# 4                0.926953            0.016935              1.325225
# ...                   ...                 ...                   ...
# 1143             0.981126            0.016543              0.483491
# 1144             0.982872            0.016543              0.518905
# 1145             0.988654            0.016543              0.347153
# 1146             0.979152            0.016543              0.464316
# 1147             0.978070            0.016543              0.946724
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.535758                 4.783760  ...
# 1                     5.997071                 7.018773  ...
# 2                     2.306566                 3.765380  ...
# 3                     5.997071                 5.076948  ...
# 4                     0.922626                 5.394173  ...
# ...                        ...                      ...  ...
# 1143                  0.472245                 1.934547  ...
# 1144                  0.472245                 1.538961  ...
# 1145                  0.472245                 2.183934  ...
# 1146                  0.472245                 1.733627  ...
# 1147                  0.472245                 4.767357  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.216851     0.057595    -0.123856     0.594318
# 1                    0.073888    -0.220058    -0.415200     0.664340
# 2                    0.177183    -0.193035    -0.285993     0.714811
# 3                    0.237313    -0.082978     0.007834     0.637973
# 4                    0.173703     0.009580     0.169398     0.605772
# ...                       ...          ...          ...          ...
# 1143                 0.087974    -0.391642    -0.562127     0.912561
# 1144                 0.090949     0.383206     0.304608     0.943293
# 1145                 0.085143    -0.187551    -0.418936     0.842823
# 1146                 0.054262    -0.494100    -0.590044     0.916520
# 1147                 0.073968     0.111211     0.153465     0.895868
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.382591  0.122478            1.382740            1.617914
# 1         0.170429  0.091237            1.459578            1.052344
# 2        -0.011644  0.449817            1.664570            1.567664
# 3         0.196542  0.341263            1.456162            1.780506
# 4         0.258683  0.365241            1.330382            1.598731
# ...            ...       ...                 ...                 ...
# 1143     -0.494243  0.091467            0.719994            1.765990
# 1144     -0.523889  0.131342            0.681876            1.699226
# 1145     -0.494132  0.064215            0.696150            1.183135
# 1146     -0.518783  0.049235            0.659370            1.079353
# 1147      0.122951  0.020529            0.713392            0.725106
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 1143  non-void             41
# 1144  non-void             41
# 1145  non-void             41
# 1146  non-void             41
# 1147  non-void             41
#
# [1148 rows x 85 columns]

# %% [markdown]
# ## Data 4c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 4s
#
# filename: two_class_raw_4s_yo_0.8.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=4.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.81it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.92it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.49it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.21it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.68it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.54it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.40it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.44it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.46it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.42it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.77it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.28it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.55it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.99it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.56it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.94it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.97it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.62it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.47it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 17.26it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_4s_0.8.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        1.998371    0.895036   0.748686      1.361620   17.055717
# 1        2.794333    0.833254   0.676522      1.151995   14.364272
# 2        3.590294    0.643343   0.329404      0.522398    9.772603
# 3        4.386256    0.602633   0.553150      0.669142   11.657440
# 4        5.182217    0.569451   0.682941      0.790683   15.973025
# ...           ...         ...        ...           ...         ...
# 2850    35.353098   -0.124197   0.543462      0.310776    3.362578
# 2851    36.147178   -0.357938   0.315084      0.227398    3.176665
# 2852    36.941258   -0.437636   0.147690      0.213337    3.064425
# 2853    37.735338   -0.399255   0.164655      0.186515    3.057450
# 2854    38.529418   -0.351928   0.147114      0.145495    2.942688
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.933704            0.016935              0.721129
# 1                0.932624            0.016935              0.821885
# 2                0.956665            0.016935              1.293173
# 3                0.933535            0.016935              0.988422
# 4                0.905800            0.016935              0.958255
# ...                   ...                 ...                   ...
# 2850             0.982179            0.016543              0.284449
# 2851             0.983990            0.016543              0.546518
# 2852             0.987127            0.016543              1.040378
# 2853             0.981288            0.016543              0.889568
# 2854             0.977836            0.016543              0.995260
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.535758                 4.783760  ...
# 1                     2.306566                 4.126660  ...
# 2                     5.535758                 6.599218  ...
# 3                     5.535758                 7.018464  ...
# 4                     0.461313                 3.945885  ...
# ...                        ...                      ...  ...
# 2850                  0.472245                 1.480385  ...
# 2851                  0.472245                 2.091256  ...
# 2852                  0.472245                 7.692625  ...
# 2853                  0.472245                 4.544649  ...
# 2854                  0.472245                 4.153331  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.216851     0.057595    -0.123856     0.594318
# 1                    0.042831     0.067296    -0.216927     0.695097
# 2                    0.063511    -0.220554    -0.345623     0.667577
# 3                    0.070615    -0.115024    -0.376673     0.683565
# 4                    0.093801    -0.136942    -0.222975     0.700738
# ...                       ...          ...          ...          ...
# 2850                 0.072581    -0.478103    -0.662771     0.878946
# 2851                 0.052474    -0.479446    -0.565518     0.915432
# 2852                 0.056008     0.108805     0.145466     0.913638
# 2853                 0.083897     0.156929     0.212056     0.904841
# 2854                 0.081605    -0.004389     0.000494     0.891618
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.382591  0.122478            1.382740            1.617914
# 1         0.313445  0.116908            1.437198            1.259782
# 2         0.211965  0.076889            1.414341            0.828408
# 3         0.188017  0.141010            1.542166            1.195111
# 4         0.096305  0.314774            1.590110            1.388882
# ...            ...       ...                 ...                 ...
# 2850     -0.535084  0.060621            0.657649            1.092732
# 2851     -0.520991  0.047146            0.660932            1.070773
# 2852      0.129272  0.022113            0.694571            0.722838
# 2853      0.151337  0.022148            0.711944            0.704397
# 2854      0.133618  0.014576            0.710537            0.751294
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 2850  non-void             41
# 2851  non-void             41
# 2852  non-void             41
# 2853  non-void             41
# 2854  non-void             41
#
# [2855 rows x 85 columns]

# %% [markdown]
# ## Data 5
# classes: void, non-void
#
# fs: original
#
# overlap: 0.0
#
# sliding window: 5s
#
# filename: two_class_raw_5s_no.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=5.0, overlap=0.0)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 76.89it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 95.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 57.82it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 63.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 99.54it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 62.31it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 83.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 46.14it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.45it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 39.86it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.77it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 69.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 51.41it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 116.30it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 98.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 86.39it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 37.18it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 89.64it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 112.65it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 99.92it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 39.37it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 67.51it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.21it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.17it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 53.35it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 25.53it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 75.24it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 91.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 76.13it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 68.88it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 107.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 77.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 98.70it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 64.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 44.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 85.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 96.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.18it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 82.34it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_5s_no.csv', index=False)
final_features
# Out:
#      center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0       2.497964    0.833686   0.688622      1.169233   15.691631
# 1       7.493893    0.597887   0.699962      0.847416   17.382356
# 2      12.489822    0.505559   0.478334      0.484393   12.490924
# 3      17.485750    0.319619   0.915191      0.939730   10.836993
# 4      22.481679    0.984424   0.390305      1.121429    7.930420
# ..           ...         ...        ...           ...         ...
# 460    17.486301    0.495251   0.126030      0.261157    3.735106
# 461    22.482387    0.602377   0.141104      0.382768    3.276323
# 462    27.478473    0.717196   0.156163      0.538757    3.923895
# 463    32.474559    0.452289   0.411578      0.373962    4.124711
# 464    37.470645   -0.400398   0.156707      0.184876    3.069228
#
#      acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0               0.933892            0.016935              0.815896
# 1               0.904367            0.016935              1.128113
# 2               0.913832            0.016935              1.302996
# 3               0.961483            0.016935              0.570453
# 4               0.980729            0.016935              1.253081
# ..                   ...                 ...                   ...
# 460             0.980471            0.016543              1.242064
# 461             0.988255            0.016543              1.155217
# 462             0.988171            0.016543              1.189028
# 463             0.983118            0.016543              0.549684
# 464             0.982395            0.016543              1.046769
#
#      acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                    5.535758                 4.853708  ...
# 1                    5.997071                 4.312535  ...
# 2                    3.229192                 5.510294  ...
# 3                    0.461313                 6.076926  ...
# 4                    0.461313                 5.766811  ...
# ..                        ...                      ...  ...
# 460                  0.472245                 5.373809  ...
# 461                  0.472245                 6.919583  ...
# 462                  0.472245                 6.099198  ...
# 463                  0.472245                 1.734082  ...
# 464                  0.472245                 5.374848  ...
#
#      gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                   0.160094    -0.008450    -0.204499     0.642213
# 1                   0.247240    -0.174339    -0.208124     0.662307
# 2                   0.183133     0.087968     0.355857     0.609023
# 3                   0.082872    -0.214670    -0.302200     0.649357
# 4                   0.069111    -0.268736    -0.292934     0.666481
# ..                       ...          ...          ...          ...
# 460                 0.099316    -0.088897    -0.111420     0.956869
# 461                 0.080861     0.438385     0.422745     0.960081
# 462                 0.074021     0.502067     0.506366     0.952155
# 463                 0.082063     0.235451     0.148637     0.930147
# 464                 0.062430     0.191614     0.243774     0.913524
#
#      acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0        0.268746  0.149712            1.490904            1.466923  non-void
# 1        0.160058  0.421337            1.500251            1.820409  non-void
# 2        0.330021  0.145964            1.197521            1.251777  non-void
# 3        0.462938  0.126187            1.459506            1.377422      void
# 4       -0.041202  0.028393            2.041217            0.861220      void
# ..            ...       ...                 ...                 ...       ...
# 460     -0.526379  0.011950            1.678247            1.106769      void
# 461     -0.177986  0.003536            1.782526            0.856462      void
# 462     -0.014039  0.031198            1.004702            0.959015      void
# 463     -0.521870  0.153890            0.638233            1.784415  non-void
# 464      0.106597  0.023891            0.691152            0.720251  non-void
#
#      experiment_id
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 460             41
# 461             41
# 462             41
# 463             41
# 464             41
#
# [465 rows x 85 columns]

# %% [markdown]
# ## Data 5b
# classes: void, non-void
#
# fs: original
#
# overlap: 0.5
#
# sliding window: 5s
#
# filename: two_class_raw_5s_yo_0.5.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=5.0, overlap=0.5)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 38.99it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 48.46it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 30.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 51.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 24.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 40.40it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 43.27it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 25.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.90it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 37.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 28.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 64.03it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.52it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 47.65it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.00it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 52.55it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 56.61it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 49.20it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.65it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 39.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 32.96it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 22.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.22it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.22it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 52.11it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 38.70it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 36.95it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 70.12it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 41.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 50.43it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 29.69it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 31.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.73it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 46.25it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 54.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.36it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 46.76it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_5s_0.5.csv', index=False)
final_features
# Out:
#      center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0       2.497964    0.833686   0.688622      1.169233   15.691631
# 1       5.004396    0.619580   0.656177      0.814448   15.264157
# 2       7.510828    0.595686   0.700628      0.845721   17.371547
# 3      10.017260    0.634790   0.432010      0.589591   12.569248
# 4      12.523692    0.505274   0.478102      0.483884   12.399092
# ..           ...         ...        ...           ...         ...
# 900    27.478473    0.717196   0.156163      0.538757    3.923895
# 901    29.976516    0.549039   0.389334      0.453024    3.992223
# 902    32.474559    0.452289   0.411578      0.373962    4.124711
# 903    34.972602    0.032065   0.611131      0.374509    3.534878
# 904    37.470645   -0.400398   0.156707      0.184876    3.069228
#
#      acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0               0.933892            0.016935              0.815896
# 1               0.916663            0.016935              0.972591
# 2               0.904974            0.016935              1.119555
# 3               0.926678            0.016935              1.416838
# 4               0.912642            0.016935              1.325424
# ..                   ...                 ...                   ...
# 900             0.988171            0.016543              1.189028
# 901             0.984925            0.016543              0.502883
# 902             0.983118            0.016543              0.549684
# 903             0.985500            0.016543              0.260790
# 904             0.982395            0.016543              1.046769
#
#      acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                    5.535758                 4.853708  ...
# 1                    0.461313                 3.597922  ...
# 2                    5.997071                 4.321277  ...
# 3                    0.922626                 5.196848  ...
# 4                    3.229192                 5.554571  ...
# ..                        ...                      ...  ...
# 900                  0.472245                 6.099198  ...
# 901                  0.472245                 2.518631  ...
# 902                  0.472245                 1.734082  ...
# 903                  0.472245                 1.704404  ...
# 904                  0.472245                 5.374848  ...
#
#      gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                   0.160094    -0.008450    -0.204499     0.642213
# 1                   0.111833    -0.154433    -0.231321     0.671232
# 2                   0.247824    -0.174816    -0.205896     0.659434
# 3                   0.218247     0.017786     0.159564     0.629451
# 4                   0.187358     0.088548     0.356868     0.608757
# ..                       ...          ...          ...          ...
# 900                 0.074021     0.502067     0.506366     0.952155
# 901                 0.074436    -0.238914    -0.383357     0.931418
# 902                 0.082063     0.235451     0.148637     0.930147
# 903                 0.072802    -0.341350    -0.551458     0.878566
# 904                 0.062430     0.191614     0.243774     0.913524
#
#      acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean     label  \
# 0        0.268746  0.149712            1.490904            1.466923  non-void
# 1        0.151762  0.298160            1.511610            1.304978  non-void
# 2        0.165140  0.426601            1.494697            1.821169  non-void
# 3        0.206477  0.354994            1.348802            1.559237  non-void
# 4        0.330102  0.146376            1.199234            1.251726  non-void
# ..            ...       ...                 ...                 ...       ...
# 900     -0.014039  0.031198            1.004702            0.959015      void
# 901     -0.529274  0.091513            0.758872            1.607015  non-void
# 902     -0.521870  0.153890            0.638233            1.784415  non-void
# 903     -0.551078  0.055087            0.702076            1.001189  non-void
# 904      0.106597  0.023891            0.691152            0.720251  non-void
#
#      experiment_id
# 0                1
# 1                1
# 2                1
# 3                1
# 4                1
# ..             ...
# 900             41
# 901             41
# 902             41
# 903             41
# 904             41
#
# [905 rows x 85 columns]

# %% [markdown]
# ## Data 5c
# classes: void, non-void
#
# fs: original
#
# overlap: 0.8
#
# sliding window: 5s
#
# filename: two_class_raw_5s_yo_0.8.csv

# %%
all_features = []
for exp_id, imu_data in enumerate(labelled_imu_dict.keys()):    
    # Extract features
    
    df = labelled_imu_dict[imu_data]    
    fs = 1 / df['time'].diff().median()
    analyzer = GenerateFeatures(fs, window_duration=5.0, overlap=0.8)
    features, _ = analyzer.analyze_multi_axis_imu(labelled_imu_dict[imu_data])

    table = analyzer.create_summary_table()
    table['experiment_id'] = exp_id + 1  # Track source
    all_features.append(table)
    

final_features = pd.concat(all_features, ignore_index=True)
# Out:
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.22it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.45it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.18it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.69it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.00it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 10.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.50it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.06it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.55it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  8.28it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.59it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.34it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 27.29it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  7.91it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.76it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 23.05it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.98it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.34it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.72it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 12.84it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  9.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.11it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00,  5.23it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.60it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 15.57it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 14.67it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.78it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 16.01it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 20.54it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 13.08it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 11.19it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 18.69it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 21.07it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:01<00:00,  3.66it/s]
# Analyzing signals: 100%|██████████| 5/5 [00:00<00:00, 19.28it/s]

# %%
final_features.to_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_4/two_class_raw_5s_0.8.csv', index=False)
final_features
# Out:
#       center_time  acc_x_mean  acc_x_std  acc_x_energy  acc_x_jerk  \
# 0        2.497964    0.833686   0.688622      1.169233   15.691631
# 1        3.497150    0.680944   0.584940      0.805840   12.807200
# 2        4.496336    0.646347   0.549188      0.719371   13.218291
# 3        5.495521    0.633710   0.663685      0.842065   15.591740
# 4        6.494707    0.607837   0.655408      0.799025   15.600146
# ...           ...         ...        ...           ...         ...
# 2238    34.261238    0.214183   0.608492      0.416137    3.523924
# 2239    35.253838   -0.038777   0.594069      0.354422    3.347236
# 2240    36.246438   -0.261329   0.392532      0.222374    3.231489
# 2241    37.239038   -0.398670   0.158961      0.184207    3.187045
# 2242    38.231638   -0.387104   0.156872      0.174458    3.082575
#
#       acc_x_autocorr_peak  acc_x_autocorr_lag  acc_x_sample_entropy  \
# 0                0.933892            0.016935              0.815896
# 1                0.927355            0.016935              0.992115
# 2                0.932091            0.016935              1.096323
# 3                0.916622            0.016935              1.052211
# 4                0.915122            0.016935              1.054250
# ...                   ...                 ...                   ...
# 2238             0.990189            0.016543              0.309091
# 2239             0.988610            0.016543              0.248569
# 2240             0.984082            0.016543              0.440879
# 2241             0.983732            0.016543              1.036999
# 2242             0.979856            0.016543              0.986083
#
#       acc_x_dominant_frequency  acc_x_spectral_centroid  ...  \
# 0                     5.535758                 4.853708  ...
# 1                     5.997071                 5.732905  ...
# 2                     0.461313                 4.923995  ...
# 3                     2.306566                 4.119854  ...
# 4                     5.997071                 4.273793  ...
# ...                        ...                      ...  ...
# 2238                  0.472245                 1.704196  ...
# 2239                  0.472245                 1.584962  ...
# 2240                  0.472245                 1.758453  ...
# 2241                  0.472245                 5.236208  ...
# 2242                  0.472245                 5.467441  ...
#
#       gyr_mag_high_band_power  acc_xy_corr  acc_xz_corr  acc_yz_corr  \
# 0                    0.160094    -0.008450    -0.204499     0.642213
# 1                    0.058255    -0.109024    -0.418378     0.687438
# 2                    0.072402    -0.203705    -0.353001     0.664274
# 3                    0.162763    -0.191295    -0.278731     0.707437
# 4                    0.192523    -0.175506    -0.275325     0.700469
# ...                       ...          ...          ...          ...
# 2238                 0.080257    -0.313596    -0.515971     0.874112
# 2239                 0.073905    -0.397834    -0.579488     0.896929
# 2240                 0.060920    -0.500245    -0.627450     0.909248
# 2241                 0.070222     0.102914     0.139137     0.914421
# 2242                 0.072972     0.173701     0.216000     0.901971
#
#       acc_gyr_corr  tilt_var  acc_magnitude_mean  gyr_magnitude_mean  \
# 0         0.268746  0.149712            1.490904            1.466923
# 1         0.194171  0.117704            1.476697            1.306016
# 2         0.202576  0.227829            1.492238            1.181991
# 3         0.096704  0.377026            1.548377            1.428480
# 4        -0.009021  0.406979            1.607442            1.571665
# ...            ...       ...                 ...                 ...
# 2238     -0.469103  0.072364            0.696956            1.174356
# 2239     -0.470004  0.058204            0.705968            1.051261
# 2240     -0.419773  0.062533            0.650583            1.032746
# 2241     -0.200275  0.025160            0.679709            0.786416
# 2242      0.129435  0.019965            0.714115            0.742004
#
#          label  experiment_id
# 0     non-void              1
# 1     non-void              1
# 2     non-void              1
# 3     non-void              1
# 4     non-void              1
# ...        ...            ...
# 2238  non-void             41
# 2239  non-void             41
# 2240  non-void             41
# 2241  non-void             41
# 2242  non-void             41
#
# [2243 rows x 85 columns]
