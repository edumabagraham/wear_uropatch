# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt
import numpy as np

# %%
raw = pd.read_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/feature_set_2/three_class_raw_5s_0.5.csv')
ohne_gravity = pd.read_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/preprocessed/feature_set_2/without_gravity/three_class_pp_5s_0.5.csv')
mit_gravity = pd.read_csv('/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/feature_datasets/subject_based_norm/preprocessed/feature_set_2/with_gravity/three_class_pp_5s_0.5.csv')

# %%
# plt.plot(raw['gyr_mag_mean'])

# px.scatter(raw['gyr_mag_mean'])
px.scatter(raw[raw['experiment_id'] == 20]['gyr_mag_mean'])

# %%
raw[raw['experiment_id'] == 20]['label']
# Out:
# 403     pre-void
# 404     pre-void
# 405     pre-void
# 406         void
# 407         void
# 408         void
# 409         void
# 410         void
# 411         void
# 412    post-void
# 413    post-void
# 414    post-void
# Name: label, dtype: object

# %%
# px.scatter(ohne_gravity['gyr_mag_mean'])
px.scatter(ohne_gravity[ohne_gravity['experiment_id'] == 20]['gyr_mag_mean'])

# %%
ohne_gravity[ohne_gravity['experiment_id'] == 20]['label']
# Out:
# 403     pre-void
# 404     pre-void
# 405     pre-void
# 406         void
# 407         void
# 408         void
# 409         void
# 410         void
# 411         void
# 412    post-void
# 413    post-void
# 414    post-void
# Name: label, dtype: object

# %%
# px.scatter(mit_gravity['gyr_mag_mean'])
px.scatter(mit_gravity[mit_gravity['experiment_id'] == 20]['gyr_mag_mean'])

# %%
mit_gravity[mit_gravity['experiment_id'] == 20]['label']
# Out:
# 403     pre-void
# 404     pre-void
# 405     pre-void
# 406         void
# 407         void
# 408         void
# 409         void
# 410         void
# 411         void
# 412    post-void
# 413    post-void
# 414    post-void
# Name: label, dtype: object
