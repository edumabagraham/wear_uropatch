# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Two class

# %% [markdown]
# Raw

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np

# Create the dataset
data = [
    # DecisionTree
    {'condition': '1s_no', 'model': 'DecisionTree', 'mean': 0.5993, 'std': 0.094, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'DecisionTree', 'mean': 0.6755, 'std': 0.0414, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'DecisionTree', 'mean': 0.6601, 'std': 0.0504, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'DecisionTree', 'mean': 0.644, 'std': 0.0374, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'DecisionTree', 'mean': 0.6584, 'std': 0.057, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'DecisionTree', 'mean': 0.6559, 'std': 0.0673, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'DecisionTree', 'mean': 0.653, 'std': 0.0802, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'DecisionTree', 'mean': 0.6125, 'std': 0.1218, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'DecisionTree', 'mean': 0.6081, 'std': 0.0747, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'DecisionTree', 'mean': 0.6357, 'std': 0.0898, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'DecisionTree', 'mean': 0.6574, 'std': 0.0647, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'DecisionTree', 'mean': 0.6468, 'std': 0.0487, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'DecisionTree', 'mean': 0.5887, 'std': 0.0721, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'DecisionTree', 'mean': 0.6478, 'std': 0.0881, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'DecisionTree', 'mean': 0.6791, 'std': 0.1311, 'window_size': '5s', 'overlap': '80%'},
    
    # RandomForest
    {'condition': '1s_no', 'model': 'RandomForest', 'mean': 0.6103, 'std': 0.0658, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'RandomForest', 'mean': 0.6287, 'std': 0.1154, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'RandomForest', 'mean': 0.6239, 'std': 0.0519, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'RandomForest', 'mean': 0.6226, 'std': 0.0816, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'RandomForest', 'mean': 0.6511, 'std': 0.0847, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'RandomForest', 'mean': 0.6532, 'std': 0.0908, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'RandomForest', 'mean': 0.6576, 'std': 0.083, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'RandomForest', 'mean': 0.6209, 'std': 0.1178, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'RandomForest', 'mean': 0.6307, 'std': 0.1101, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'RandomForest', 'mean': 0.6544, 'std': 0.0486, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'RandomForest', 'mean': 0.6211, 'std': 0.13, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'RandomForest', 'mean': 0.661, 'std': 0.0695, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'RandomForest', 'mean': 0.653, 'std': 0.1135, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'RandomForest', 'mean': 0.6704, 'std': 0.1388, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'RandomForest', 'mean': 0.6792, 'std': 0.1276, 'window_size': '5s', 'overlap': '80%'},
    
    # XGBoost
    {'condition': '1s_no', 'model': 'XGBoost', 'mean': 0.5589, 'std': 0.0805, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'XGBoost', 'mean': 0.5908, 'std': 0.1137, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'XGBoost', 'mean': 0.6091, 'std': 0.0574, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'XGBoost', 'mean': 0.6231, 'std': 0.0927, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'XGBoost', 'mean': 0.6293, 'std': 0.0771, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'XGBoost', 'mean': 0.6126, 'std': 0.0662, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'XGBoost', 'mean': 0.6596, 'std': 0.0912, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'XGBoost', 'mean': 0.584, 'std': 0.1286, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'XGBoost', 'mean': 0.6299, 'std': 0.0887, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'XGBoost', 'mean': 0.6093, 'std': 0.0769, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'XGBoost', 'mean': 0.6023, 'std': 0.0822, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'XGBoost', 'mean': 0.6786, 'std': 0.0606, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'XGBoost', 'mean': 0.6361, 'std': 0.112, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'XGBoost', 'mean': 0.574, 'std': 0.1032, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'XGBoost', 'mean': 0.6514, 'std': 0.0799, 'window_size': '5s', 'overlap': '80%'}
]

# Create DataFrame
df = pd.DataFrame(data)

# Add performance score
df['performance_score'] = df['mean'] - df['std']

# Define colors for each model
model_colors = {
    'DecisionTree': '#e74c3c',
    'RandomForest': '#2ecc71', 
    'XGBoost': '#3498db'
}

# Create the main scatter plot
fig = px.scatter(
    df, 
    x='std', 
    y='mean',
    color='model',
    hover_data=['condition', 'window_size', 'overlap'],
    color_discrete_map=model_colors,
    title='Binary Classification F1-Scores: Standard Deviation vs Mean',
    labels={
        'std': 'F1-Score Standard Deviation',
        'mean': 'Mean F1-Score',
        'model': 'Model'
    }
)

# Update traces for better styling
fig.update_traces(
    marker=dict(size=12, opacity=0.8, line=dict(width=2, color='white')),
    hovertemplate='<b>%{fullData.name}</b><br>' +
                  'Condition: %{customdata[0]}<br>' +
                #   'Window: %{customdata[1]}<br>' +
                #   'Overlap: %{customdata[2]}<br>' +
                  'F1-Score: %{y:.4f}<br>' +
                  'Std Dev: %{x:.4f}<extra></extra>'
)


# Update layout
fig.update_layout(
    width=1000,
    height=600,
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(size=12),
    title_font_size=16,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5
    ),
    margin=dict(t=60, b=100, l=80, r=40)
)

# Update axes
fig.update_xaxes(
    gridcolor='#ecf0f1',
    tickformat='.3f',
    title_font_size=14
)
fig.update_yaxes(
    gridcolor='#ecf0f1', 
    tickformat='.3f',
    title_font_size=14
)

# Show the plot
fig.show()

# Print best performers summary
print("🏆 BEST PERFORMERS BY MODEL:")
print("=" * 50)

for model in df['model'].unique():
    model_data = df[df['model'] == model]
    best_performer = model_data.loc[model_data['performance_score'].idxmax()]
    
    overlap_text = {
        'no': 'No Overlap',
        '50%': '50% Overlap', 
        '80%': '80% Overlap'
    }[best_performer['overlap']]
    
    print(f"\n{model}:")
    print(f"  Best Configuration: {best_performer['condition']}")
    print(f"  Window: {best_performer['window_size']}, {overlap_text}")
    print(f"  F1-Score: {best_performer['mean']:.4f}")
    print(f"  Std Dev: {best_performer['std']:.4f}")
    print(f"  Performance Score: {best_performer['performance_score']:.4f}")

# Additional analysis functions
def filter_by_model(model_name):
    """Filter data by specific model"""
    return df[df['model'] == model_name]

def filter_by_overlap(overlap_type):
    """Filter data by overlap type ('no', '50%', '80%')"""
    return df[df['overlap'] == overlap_type]

def filter_by_window_size(window_size):
    """Filter data by window size ('1s', '2s', '3s', '4s', '5s')"""
    return df[df['window_size'] == window_size]

def get_top_performers(n=5):
    """Get top N performers by performance score"""
    return df.nlargest(n, 'performance_score')[['model', 'condition', 'mean', 'std', 'performance_score']]

# Example usage of analysis functions:
print(f"\n🎯 TOP 5 OVERALL PERFORMERS:")
print("=" * 50)
top_5 = get_top_performers(5)
for idx, row in top_5.iterrows():
    print(f"{top_5.index.get_loc(idx) + 1}. {row['model']} - {row['condition']}: "
          f"F1={row['mean']:.4f}, Std={row['std']:.4f}, Score={row['performance_score']:.4f}")

# Export functionality
print(f"\n📸 TO EXPORT THE PLOT:")
print("- Use fig.write_image('f1_scores.png') for PNG")
print("- Use fig.write_image('f1_scores.pdf') for PDF") 
print("- Use fig.write_html('f1_scores.html') for interactive HTML")
print("- Or use the camera icon in the plot toolbar when displayed")
# Out:
# 🏆 BEST PERFORMERS BY MODEL:
# ...
#
# DecisionTree:
#   Best Configuration: 1s_0.5
#   Window: 1s, 50% Overlap
#   F1-Score: 0.6755
#   Std Dev: 0.0414
#   Performance Score: 0.6341
#
# RandomForest:
#   Best Configuration: 4s_no
#   Window: 4s, No Overlap
#   F1-Score: 0.6544
#   Std Dev: 0.0486
#   Performance Score: 0.6058
#
# XGBoost:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.6786
#   Std Dev: 0.0606
#   Performance Score: 0.6180
#
# 🎯 TOP 5 OVERALL PERFORMERS:
# ...
# 1. DecisionTree - 1s_0.5: F1=0.6755, Std=0.0414, Score=0.6341
# 2. XGBoost - 4s_0.8: F1=0.6786, Std=0.0606, Score=0.6180
# 3. DecisionTree - 1s_0.8: F1=0.6601, Std=0.0504, Score=0.6097
# 4. DecisionTree - 2s_no: F1=0.6440, Std=0.0374, Score=0.6066
# 5. RandomForest - 4s_no: F1=0.6544, Std=0.0486, Score=0.6058
#
# 📸 TO EXPORT THE PLOT:
# - Use fig.write_image('f1_scores.png') for PNG
# - Use fig.write_image('f1_scores.pdf') for PDF
# - Use fig.write_html('f1_scores.html') for interactive HTML
# ...

# %% [markdown]
# Oversample

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np

# Create the dataset
data = [
    # DecisionTree
    {'condition': '1s_no', 'model': 'DecisionTree', 'mean': 0.6267, 'std': 0.1226, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'DecisionTree', 'mean': 0.632, 'std': 0.0761, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'DecisionTree', 'mean': 0.6527, 'std': 0.0472, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'DecisionTree', 'mean': 0.6531, 'std': 0.0728, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'DecisionTree', 'mean': 0.6697, 'std': 0.0642, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'DecisionTree', 'mean': 0.651, 'std': 0.065, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'DecisionTree', 'mean': 0.6551, 'std': 0.0382, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'DecisionTree', 'mean': 0.6763, 'std': 0.0955, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'DecisionTree', 'mean': 0.6666, 'std': 0.055, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'DecisionTree', 'mean': 0.5676, 'std': 0.1303, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'DecisionTree', 'mean': 0.6243, 'std': 0.1113, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'DecisionTree', 'mean': 0.662, 'std': 0.054, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'DecisionTree', 'mean': 0.6551, 'std': 0.057, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'DecisionTree', 'mean': 0.676, 'std': 0.0757, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'DecisionTree', 'mean': 0.6538, 'std': 0.1388, 'window_size': '5s', 'overlap': '80%'},
    
    # RandomForest
    {'condition': '1s_no', 'model': 'RandomForest', 'mean': 0.6539, 'std': 0.0605, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'RandomForest', 'mean': 0.6736, 'std': 0.0577, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'RandomForest', 'mean': 0.6734, 'std': 0.0621, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'RandomForest', 'mean': 0.6587, 'std': 0.0557, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'RandomForest', 'mean': 0.6801, 'std': 0.0722, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'RandomForest', 'mean': 0.6714, 'std': 0.0886, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'RandomForest', 'mean': 0.6993, 'std': 0.0792, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'RandomForest', 'mean': 0.6834, 'std': 0.0946, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'RandomForest', 'mean': 0.6873, 'std': 0.0699, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'RandomForest', 'mean': 0.6645, 'std': 0.0496, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'RandomForest', 'mean': 0.6643, 'std': 0.111, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'RandomForest', 'mean': 0.7076, 'std': 0.0548, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'RandomForest', 'mean': 0.6817, 'std': 0.0607, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'RandomForest', 'mean': 0.6944, 'std': 0.1059, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'RandomForest', 'mean': 0.7158, 'std': 0.0981, 'window_size': '5s', 'overlap': '80%'},
    
    # XGBoost
    {'condition': '1s_no', 'model': 'XGBoost', 'mean': 0.6084, 'std': 0.0909, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'XGBoost', 'mean': 0.6497, 'std': 0.0639, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'XGBoost', 'mean': 0.6527, 'std': 0.0509, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'XGBoost', 'mean': 0.64, 'std': 0.0678, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'XGBoost', 'mean': 0.6604, 'std': 0.0834, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'XGBoost', 'mean': 0.6626, 'std': 0.08, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'XGBoost', 'mean': 0.6752, 'std': 0.081, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'XGBoost', 'mean': 0.6693, 'std': 0.0966, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'XGBoost', 'mean': 0.6869, 'std': 0.0369, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'XGBoost', 'mean': 0.6551, 'std': 0.0252, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'XGBoost', 'mean': 0.6109, 'std': 0.1022, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'XGBoost', 'mean': 0.7013, 'std': 0.0576, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'XGBoost', 'mean': 0.6547, 'std': 0.0799, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'XGBoost', 'mean': 0.6609, 'std': 0.0706, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'XGBoost', 'mean': 0.6915, 'std': 0.0574, 'window_size': '5s', 'overlap': '80%'}
]

# Create DataFrame
df = pd.DataFrame(data)

# Add performance score
df['performance_score'] = df['mean'] - df['std']

# Define colors for each model
model_colors = {
    'DecisionTree': '#e74c3c',
    'RandomForest': '#2ecc71', 
    'XGBoost': '#3498db'
}

# Create the main scatter plot
fig = px.scatter(
    df, 
    x='std', 
    y='mean',
    color='model',
    hover_data=['condition', 'window_size', 'overlap'],
    color_discrete_map=model_colors,
    title='Binary Classification F1-Scores: Standard Deviation vs Mean',
    labels={
        'std': 'F1-Score Standard Deviation',
        'mean': 'Mean F1-Score',
        'model': 'Model'
    }
)

# Update traces for better styling
fig.update_traces(
    marker=dict(size=12, opacity=0.8, line=dict(width=2, color='white')),
    hovertemplate='<b>%{fullData.name}</b><br>' +
                  'Condition: %{customdata[0]}<br>' +
                #   'Window: %{customdata[1]}<br>' +
                #   'Overlap: %{customdata[2]}<br>' +
                  'F1-Score: %{y:.4f}<br>' +
                  'Std Dev: %{x:.4f}<extra></extra>'
)


# Update layout
fig.update_layout(
    width=1000,
    height=600,
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(size=12),
    title_font_size=16,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5
    ),
    margin=dict(t=60, b=100, l=80, r=40)
)

# Update axes
fig.update_xaxes(
    gridcolor='#ecf0f1',
    tickformat='.3f',
    title_font_size=14
)
fig.update_yaxes(
    gridcolor='#ecf0f1', 
    tickformat='.3f',
    title_font_size=14
)

# Show the plot
fig.show()

# Print best performers summary
print("🏆 BEST PERFORMERS BY MODEL:")
print("=" * 50)

for model in df['model'].unique():
    model_data = df[df['model'] == model]
    best_performer = model_data.loc[model_data['performance_score'].idxmax()]
    
    overlap_text = {
        'no': 'No Overlap',
        '50%': '50% Overlap', 
        '80%': '80% Overlap'
    }[best_performer['overlap']]
    
    print(f"\n{model}:")
    print(f"  Best Configuration: {best_performer['condition']}")
    print(f"  Window: {best_performer['window_size']}, {overlap_text}")
    print(f"  F1-Score: {best_performer['mean']:.4f}")
    print(f"  Std Dev: {best_performer['std']:.4f}")
    print(f"  Performance Score: {best_performer['performance_score']:.4f}")

# Additional analysis functions
def filter_by_model(model_name):
    """Filter data by specific model"""
    return df[df['model'] == model_name]

def filter_by_overlap(overlap_type):
    """Filter data by overlap type ('no', '50%', '80%')"""
    return df[df['overlap'] == overlap_type]

def filter_by_window_size(window_size):
    """Filter data by window size ('1s', '2s', '3s', '4s', '5s')"""
    return df[df['window_size'] == window_size]

def get_top_performers(n=5):
    """Get top N performers by performance score"""
    return df.nlargest(n, 'performance_score')[['model', 'condition', 'mean', 'std', 'performance_score']]

# Example usage of analysis functions:
print(f"\n🎯 TOP 5 OVERALL PERFORMERS:")
print("=" * 50)
top_5 = get_top_performers(5)
for idx, row in top_5.iterrows():
    print(f"{top_5.index.get_loc(idx) + 1}. {row['model']} - {row['condition']}: "
          f"F1={row['mean']:.4f}, Std={row['std']:.4f}, Score={row['performance_score']:.4f}")

# Export functionality
print(f"\n📸 TO EXPORT THE PLOT:")
print("- Use fig.write_image('f1_scores.png') for PNG")
print("- Use fig.write_image('f1_scores.pdf') for PDF") 
print("- Use fig.write_html('f1_scores.html') for interactive HTML")
print("- Or use the camera icon in the plot toolbar when displayed")
# Out:
# 🏆 BEST PERFORMERS BY MODEL:
# ...
#
# DecisionTree:
#   Best Configuration: 3s_no
#   Window: 3s, No Overlap
#   F1-Score: 0.6551
#   Std Dev: 0.0382
#   Performance Score: 0.6169
#
# RandomForest:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.7076
#   Std Dev: 0.0548
#   Performance Score: 0.6528
#
# XGBoost:
#   Best Configuration: 3s_0.8
#   Window: 3s, 80% Overlap
#   F1-Score: 0.6869
#   Std Dev: 0.0369
#   Performance Score: 0.6500
#
# 🎯 TOP 5 OVERALL PERFORMERS:
# ...
# 1. RandomForest - 4s_0.8: F1=0.7076, Std=0.0548, Score=0.6528
# 2. XGBoost - 3s_0.8: F1=0.6869, Std=0.0369, Score=0.6500
# 3. XGBoost - 4s_0.8: F1=0.7013, Std=0.0576, Score=0.6437
# 4. XGBoost - 5s_0.8: F1=0.6915, Std=0.0574, Score=0.6341
# 5. XGBoost - 4s_no: F1=0.6551, Std=0.0252, Score=0.6299
#
# 📸 TO EXPORT THE PLOT:
# - Use fig.write_image('f1_scores.png') for PNG
# - Use fig.write_image('f1_scores.pdf') for PDF
# - Use fig.write_html('f1_scores.html') for interactive HTML
# ...

# %% [markdown]
# Undersample

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np

# Create the dataset
data = [
    # DecisionTree
    {'condition': '1s_no', 'model': 'DecisionTree', 'mean': 0.6139, 'std': 0.0558, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'DecisionTree', 'mean': 0.6497, 'std': 0.0694, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'DecisionTree', 'mean': 0.6619, 'std': 0.0473, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'DecisionTree', 'mean': 0.6633, 'std': 0.0355, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'DecisionTree', 'mean': 0.6751, 'std': 0.0683, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'DecisionTree', 'mean': 0.6551, 'std': 0.0979, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'DecisionTree', 'mean': 0.6587, 'std': 0.0328, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'DecisionTree', 'mean': 0.6619, 'std': 0.0893, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'DecisionTree', 'mean': 0.6336, 'std': 0.0804, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'DecisionTree', 'mean': 0.6281, 'std': 0.0428, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'DecisionTree', 'mean': 0.6288, 'std': 0.066, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'DecisionTree', 'mean': 0.6757, 'std': 0.0432, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'DecisionTree', 'mean': 0.6236, 'std': 0.0567, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'DecisionTree', 'mean': 0.6657, 'std': 0.0878, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'DecisionTree', 'mean': 0.6814, 'std': 0.1409, 'window_size': '5s', 'overlap': '80%'},
    
    # RandomForest
    {'condition': '1s_no', 'model': 'RandomForest', 'mean': 0.6336, 'std': 0.0601, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'RandomForest', 'mean': 0.6465, 'std': 0.0851, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'RandomForest', 'mean': 0.6334, 'std': 0.076, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'RandomForest', 'mean': 0.6451, 'std': 0.0705, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'RandomForest', 'mean': 0.6659, 'std': 0.0795, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'RandomForest', 'mean': 0.6466, 'std': 0.1029, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'RandomForest', 'mean': 0.6879, 'std': 0.075, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'RandomForest', 'mean': 0.6625, 'std': 0.0893, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'RandomForest', 'mean': 0.6542, 'std': 0.0888, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'RandomForest', 'mean': 0.6353, 'std': 0.0605, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'RandomForest', 'mean': 0.6662, 'std': 0.1344, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'RandomForest', 'mean': 0.6851, 'std': 0.0577, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'RandomForest', 'mean': 0.6747, 'std': 0.0776, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'RandomForest', 'mean': 0.6842, 'std': 0.0971, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'RandomForest', 'mean': 0.6802, 'std': 0.0981, 'window_size': '5s', 'overlap': '80%'},
    
    # XGBoost
    {'condition': '1s_no', 'model': 'XGBoost', 'mean': 0.6109, 'std': 0.0758, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'XGBoost', 'mean': 0.6306, 'std': 0.0864, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'XGBoost', 'mean': 0.6217, 'std': 0.055, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'XGBoost', 'mean': 0.6288, 'std': 0.0805, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'XGBoost', 'mean': 0.6373, 'std': 0.0957, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'XGBoost', 'mean': 0.616, 'std': 0.0723, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'XGBoost', 'mean': 0.6801, 'std': 0.0642, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'XGBoost', 'mean': 0.6722, 'std': 0.0741, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'XGBoost', 'mean': 0.6587, 'std': 0.0718, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'XGBoost', 'mean': 0.6579, 'std': 0.0396, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'XGBoost', 'mean': 0.6199, 'std': 0.093, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'XGBoost', 'mean': 0.6934, 'std': 0.0598, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'XGBoost', 'mean': 0.6599, 'std': 0.0896, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'XGBoost', 'mean': 0.6442, 'std': 0.0947, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'XGBoost', 'mean': 0.6772, 'std': 0.0771, 'window_size': '5s', 'overlap': '80%'}
]

# Create DataFrame
df = pd.DataFrame(data)

# Add performance score
df['performance_score'] = df['mean'] - df['std']

# Define colors for each model
model_colors = {
    'DecisionTree': '#e74c3c',
    'RandomForest': '#2ecc71', 
    'XGBoost': '#3498db'
}

# Create the main scatter plot
fig = px.scatter(
    df, 
    x='std', 
    y='mean',
    color='model',
    hover_data=['condition', 'window_size', 'overlap'],
    color_discrete_map=model_colors,
    title='Binary Classification F1-Scores: Standard Deviation vs Mean',
    labels={
        'std': 'F1-Score Standard Deviation',
        'mean': 'Mean F1-Score',
        'model': 'Model'
    }
)

# Update traces for better styling
fig.update_traces(
    marker=dict(size=12, opacity=0.8, line=dict(width=2, color='white')),
    hovertemplate='<b>%{fullData.name}</b><br>' +
                  'Condition: %{customdata[0]}<br>' +
                #   'Window: %{customdata[1]}<br>' +
                #   'Overlap: %{customdata[2]}<br>' +
                  'F1-Score: %{y:.4f}<br>' +
                  'Std Dev: %{x:.4f}<extra></extra>'
)


# Update layout
fig.update_layout(
    width=1000,
    height=600,
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(size=12),
    title_font_size=16,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5
    ),
    margin=dict(t=60, b=100, l=80, r=40)
)

# Update axes
fig.update_xaxes(
    gridcolor='#ecf0f1',
    tickformat='.3f',
    title_font_size=14
)
fig.update_yaxes(
    gridcolor='#ecf0f1', 
    tickformat='.3f',
    title_font_size=14
)

# Show the plot
fig.show()

# Print best performers summary
print("🏆 BEST PERFORMERS BY MODEL:")
print("=" * 50)

for model in df['model'].unique():
    model_data = df[df['model'] == model]
    best_performer = model_data.loc[model_data['performance_score'].idxmax()]
    
    overlap_text = {
        'no': 'No Overlap',
        '50%': '50% Overlap', 
        '80%': '80% Overlap'
    }[best_performer['overlap']]
    
    print(f"\n{model}:")
    print(f"  Best Configuration: {best_performer['condition']}")
    print(f"  Window: {best_performer['window_size']}, {overlap_text}")
    print(f"  F1-Score: {best_performer['mean']:.4f}")
    print(f"  Std Dev: {best_performer['std']:.4f}")
    print(f"  Performance Score: {best_performer['performance_score']:.4f}")

# Additional analysis functions
def filter_by_model(model_name):
    """Filter data by specific model"""
    return df[df['model'] == model_name]

def filter_by_overlap(overlap_type):
    """Filter data by overlap type ('no', '50%', '80%')"""
    return df[df['overlap'] == overlap_type]

def filter_by_window_size(window_size):
    """Filter data by window size ('1s', '2s', '3s', '4s', '5s')"""
    return df[df['window_size'] == window_size]

def get_top_performers(n=5):
    """Get top N performers by performance score"""
    return df.nlargest(n, 'performance_score')[['model', 'condition', 'mean', 'std', 'performance_score']]

# Example usage of analysis functions:
print(f"\n🎯 TOP 5 OVERALL PERFORMERS:")
print("=" * 50)
top_5 = get_top_performers(5)
for idx, row in top_5.iterrows():
    print(f"{top_5.index.get_loc(idx) + 1}. {row['model']} - {row['condition']}: "
          f"F1={row['mean']:.4f}, Std={row['std']:.4f}, Score={row['performance_score']:.4f}")

# Export functionality
print(f"\n📸 TO EXPORT THE PLOT:")
print("- Use fig.write_image('f1_scores.png') for PNG")
print("- Use fig.write_image('f1_scores.pdf') for PDF") 
print("- Use fig.write_html('f1_scores.html') for interactive HTML")
print("- Or use the camera icon in the plot toolbar when displayed")
# Out:
# 🏆 BEST PERFORMERS BY MODEL:
# ...
#
# DecisionTree:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.6757
#   Std Dev: 0.0432
#   Performance Score: 0.6325
#
# RandomForest:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.6851
#   Std Dev: 0.0577
#   Performance Score: 0.6274
#
# XGBoost:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.6934
#   Std Dev: 0.0598
#   Performance Score: 0.6336
#
# 🎯 TOP 5 OVERALL PERFORMERS:
# ...
# 1. XGBoost - 4s_0.8: F1=0.6934, Std=0.0598, Score=0.6336
# 2. DecisionTree - 4s_0.8: F1=0.6757, Std=0.0432, Score=0.6325
# 3. DecisionTree - 2s_no: F1=0.6633, Std=0.0355, Score=0.6278
# 4. RandomForest - 4s_0.8: F1=0.6851, Std=0.0577, Score=0.6274
# 5. DecisionTree - 3s_no: F1=0.6587, Std=0.0328, Score=0.6259
#
# 📸 TO EXPORT THE PLOT:
# - Use fig.write_image('f1_scores.png') for PNG
# - Use fig.write_image('f1_scores.pdf') for PDF
# - Use fig.write_html('f1_scores.html') for interactive HTML
# ...

# %% [markdown]
# Smotetomek

# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import numpy as np

# Create the dataset
data = [
    # DecisionTree
    {'condition': '1s_no', 'model': 'DecisionTree', 'mean': 0.6234, 'std': 0.0954, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'DecisionTree', 'mean': 0.6266, 'std': 0.0756, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'DecisionTree', 'mean': 0.6526, 'std': 0.0475, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'DecisionTree', 'mean': 0.6529, 'std': 0.0672, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'DecisionTree', 'mean': 0.6577, 'std': 0.0668, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'DecisionTree', 'mean': 0.6693, 'std': 0.0589, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'DecisionTree', 'mean': 0.6286, 'std': 0.0828, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'DecisionTree', 'mean': 0.6614, 'std': 0.0938, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'DecisionTree', 'mean': 0.6763, 'std': 0.0493, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'DecisionTree', 'mean': 0.6747, 'std': 0.0599, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'DecisionTree', 'mean': 0.6334, 'std': 0.0941, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'DecisionTree', 'mean': 0.6615, 'std': 0.047, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'DecisionTree', 'mean': 0.6549, 'std': 0.0681, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'DecisionTree', 'mean': 0.6618, 'std': 0.0916, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'DecisionTree', 'mean': 0.6601, 'std': 0.123, 'window_size': '5s', 'overlap': '80%'},
    
    # RandomForest
    {'condition': '1s_no', 'model': 'RandomForest', 'mean': 0.6454, 'std': 0.0827, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'RandomForest', 'mean': 0.6747, 'std': 0.0571, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'RandomForest', 'mean': 0.6722, 'std': 0.0641, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'RandomForest', 'mean': 0.6531, 'std': 0.0508, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'RandomForest', 'mean': 0.6845, 'std': 0.0694, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'RandomForest', 'mean': 0.6729, 'std': 0.0937, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'RandomForest', 'mean': 0.6932, 'std': 0.0974, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'RandomForest', 'mean': 0.6893, 'std': 0.0868, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'RandomForest', 'mean': 0.6915, 'std': 0.0742, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'RandomForest', 'mean': 0.6686, 'std': 0.0318, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'RandomForest', 'mean': 0.6639, 'std': 0.1235, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'RandomForest', 'mean': 0.7099, 'std': 0.0522, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'RandomForest', 'mean': 0.6815, 'std': 0.0585, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'RandomForest', 'mean': 0.6911, 'std': 0.1233, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'RandomForest', 'mean': 0.7068, 'std': 0.1089, 'window_size': '5s', 'overlap': '80%'},
    
    # XGBoost
    {'condition': '1s_no', 'model': 'XGBoost', 'mean': 0.6213, 'std': 0.0845, 'window_size': '1s', 'overlap': 'no'},
    {'condition': '1s_0.5', 'model': 'XGBoost', 'mean': 0.66, 'std': 0.0594, 'window_size': '1s', 'overlap': '50%'},
    {'condition': '1s_0.8', 'model': 'XGBoost', 'mean': 0.6573, 'std': 0.0567, 'window_size': '1s', 'overlap': '80%'},
    {'condition': '2s_no', 'model': 'XGBoost', 'mean': 0.6502, 'std': 0.0683, 'window_size': '2s', 'overlap': 'no'},
    {'condition': '2s_0.5', 'model': 'XGBoost', 'mean': 0.6588, 'std': 0.0875, 'window_size': '2s', 'overlap': '50%'},
    {'condition': '2s_0.8', 'model': 'XGBoost', 'mean': 0.6604, 'std': 0.0613, 'window_size': '2s', 'overlap': '80%'},
    {'condition': '3s_no', 'model': 'XGBoost', 'mean': 0.677, 'std': 0.0827, 'window_size': '3s', 'overlap': 'no'},
    {'condition': '3s_0.5', 'model': 'XGBoost', 'mean': 0.6698, 'std': 0.0968, 'window_size': '3s', 'overlap': '50%'},
    {'condition': '3s_0.8', 'model': 'XGBoost', 'mean': 0.6817, 'std': 0.0515, 'window_size': '3s', 'overlap': '80%'},
    {'condition': '4s_no', 'model': 'XGBoost', 'mean': 0.666, 'std': 0.0527, 'window_size': '4s', 'overlap': 'no'},
    {'condition': '4s_0.5', 'model': 'XGBoost', 'mean': 0.6412, 'std': 0.1152, 'window_size': '4s', 'overlap': '50%'},
    {'condition': '4s_0.8', 'model': 'XGBoost', 'mean': 0.699, 'std': 0.0571, 'window_size': '4s', 'overlap': '80%'},
    {'condition': '5s_no', 'model': 'XGBoost', 'mean': 0.6688, 'std': 0.0718, 'window_size': '5s', 'overlap': 'no'},
    {'condition': '5s_0.5', 'model': 'XGBoost', 'mean': 0.685, 'std': 0.0897, 'window_size': '5s', 'overlap': '50%'},
    {'condition': '5s_0.8', 'model': 'XGBoost', 'mean': 0.6801, 'std': 0.0528, 'window_size': '5s', 'overlap': '80%'}
]

# Create DataFrame
df = pd.DataFrame(data)

# Add performance score
df['performance_score'] = df['mean'] - df['std']

# Define colors for each model
model_colors = {
    'DecisionTree': '#e74c3c',
    'RandomForest': '#2ecc71', 
    'XGBoost': '#3498db'
}

# Create the main scatter plot
fig = px.scatter(
    df, 
    x='std', 
    y='mean',
    color='model',
    hover_data=['condition', 'window_size', 'overlap'],
    color_discrete_map=model_colors,
    title='Binary Classification F1-Scores: Standard Deviation vs Mean',
    labels={
        'std': 'F1-Score Standard Deviation',
        'mean': 'Mean F1-Score',
        'model': 'Model'
    }
)

# Update traces for better styling
fig.update_traces(
    marker=dict(size=12, opacity=0.8, line=dict(width=2, color='white')),
    hovertemplate='<b>%{fullData.name}</b><br>' +
                  'Condition: %{customdata[0]}<br>' +
                #   'Window: %{customdata[1]}<br>' +
                #   'Overlap: %{customdata[2]}<br>' +
                  'F1-Score: %{y:.4f}<br>' +
                  'Std Dev: %{x:.4f}<extra></extra>'
)


# Update layout
fig.update_layout(
    width=1000,
    height=600,
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(size=12),
    title_font_size=16,
    legend=dict(
        orientation="h",
        yanchor="bottom",
        y=-0.15,
        xanchor="center",
        x=0.5
    ),
    margin=dict(t=60, b=100, l=80, r=40)
)

# Update axes
fig.update_xaxes(
    gridcolor='#ecf0f1',
    tickformat='.3f',
    title_font_size=14
)
fig.update_yaxes(
    gridcolor='#ecf0f1', 
    tickformat='.3f',
    title_font_size=14
)

# Show the plot
fig.show()

# Print best performers summary
print("🏆 BEST PERFORMERS BY MODEL:")
print("=" * 50)

for model in df['model'].unique():
    model_data = df[df['model'] == model]
    best_performer = model_data.loc[model_data['performance_score'].idxmax()]
    
    overlap_text = {
        'no': 'No Overlap',
        '50%': '50% Overlap', 
        '80%': '80% Overlap'
    }[best_performer['overlap']]
    
    print(f"\n{model}:")
    print(f"  Best Configuration: {best_performer['condition']}")
    print(f"  Window: {best_performer['window_size']}, {overlap_text}")
    print(f"  F1-Score: {best_performer['mean']:.4f}")
    print(f"  Std Dev: {best_performer['std']:.4f}")
    print(f"  Performance Score: {best_performer['performance_score']:.4f}")

# Additional analysis functions
def filter_by_model(model_name):
    """Filter data by specific model"""
    return df[df['model'] == model_name]

def filter_by_overlap(overlap_type):
    """Filter data by overlap type ('no', '50%', '80%')"""
    return df[df['overlap'] == overlap_type]

def filter_by_window_size(window_size):
    """Filter data by window size ('1s', '2s', '3s', '4s', '5s')"""
    return df[df['window_size'] == window_size]

def get_top_performers(n=5):
    """Get top N performers by performance score"""
    return df.nlargest(n, 'performance_score')[['model', 'condition', 'mean', 'std', 'performance_score']]

# Example usage of analysis functions:
print(f"\n🎯 TOP 5 OVERALL PERFORMERS:")
print("=" * 50)
top_5 = get_top_performers(5)
for idx, row in top_5.iterrows():
    print(f"{top_5.index.get_loc(idx) + 1}. {row['model']} - {row['condition']}: "
          f"F1={row['mean']:.4f}, Std={row['std']:.4f}, Score={row['performance_score']:.4f}")

# Export functionality
print(f"\n📸 TO EXPORT THE PLOT:")
print("- Use fig.write_image('f1_scores.png') for PNG")
print("- Use fig.write_image('f1_scores.pdf') for PDF") 
print("- Use fig.write_html('f1_scores.html') for interactive HTML")
print("- Or use the camera icon in the plot toolbar when displayed")
# Out:
# 🏆 BEST PERFORMERS BY MODEL:
# ...
#
# DecisionTree:
#   Best Configuration: 3s_0.8
#   Window: 3s, 80% Overlap
#   F1-Score: 0.6763
#   Std Dev: 0.0493
#   Performance Score: 0.6270
#
# RandomForest:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.7099
#   Std Dev: 0.0522
#   Performance Score: 0.6577
#
# XGBoost:
#   Best Configuration: 4s_0.8
#   Window: 4s, 80% Overlap
#   F1-Score: 0.6990
#   Std Dev: 0.0571
#   Performance Score: 0.6419
#
# 🎯 TOP 5 OVERALL PERFORMERS:
# ...
# 1. RandomForest - 4s_0.8: F1=0.7099, Std=0.0522, Score=0.6577
# 2. XGBoost - 4s_0.8: F1=0.6990, Std=0.0571, Score=0.6419
# 3. RandomForest - 4s_no: F1=0.6686, Std=0.0318, Score=0.6368
# 4. XGBoost - 3s_0.8: F1=0.6817, Std=0.0515, Score=0.6302
# 5. XGBoost - 5s_0.8: F1=0.6801, Std=0.0528, Score=0.6273
#
# 📸 TO EXPORT THE PLOT:
# - Use fig.write_image('f1_scores.png') for PNG
# - Use fig.write_image('f1_scores.pdf') for PDF
# - Use fig.write_html('f1_scores.html') for interactive HTML
# ...

# %%
# decisionTree = [[0.5993,0.6755,0.6601,0.644,0.6584,0.6559,0.653,0.6125,0.6081,0.6357,0.6574,0.6468,0.5887,0.6478,0.6791],
#             [0.094,0.0414,0.0504,0.0374,0.057,0.0673,0.0802,0.1218,0.0747,0.0898,0.0647,0.0487,0.0721,0.0881,0.1311]] 

# randomForest = [[0.6103,0.6287,0.6239,0.6226,0.6511,0.6532,0.6576,0.6209,0.6307,0.6544,0.6211,0.661,0.653,0.6704,0.6792]
#                 ,[0.0658,0.1154,0.0519,0.0816,0.0847,0.0908,0.083,0.1178,0.1101,0.0486,0.13,0.0695,0.1135,0.1388,0.1276]]

# xgboost = [[0.5589,0.5908,0.6091,0.6231,0.6293,0.6126,0.6596,0.584,0.6299,0.6093,0.6023,0.6786,0.6361,0.574,0.6514]
#         ,[0.0805,0.1137,0.0574,0.0927,0.0771,0.0662,0.0912,0.1286,0.0887,0.0769,0.0882,0.0606,0.112,0.1032,0.0799]]

# %%
# decisionTree_means = [0.5993, 0.6755, 0.6601, 0.644, 0.6584, 0.6559, 0.653, 0.6125, 0.6081, 0.6357, 0.6574, 0.6468, 0.5887, 0.6478, 0.6791]
# decisionTree_stds = [0.094, 0.0414, 0.0504, 0.0374, 0.057, 0.0673, 0.0802, 0.1218, 0.0747, 0.0898, 0.0647, 0.0487, 0.0721, 0.0881, 0.1311]

# randomForest_means = [0.6103, 0.6287, 0.6239, 0.6226, 0.6511, 0.6532, 0.6576, 0.6209, 0.6307, 0.6544, 0.6211, 0.661, 0.653, 0.6704, 0.6792]
# randomForest_stds = [0.0658, 0.1154, 0.0519, 0.0816, 0.0847, 0.0908, 0.083, 0.1178, 0.1101, 0.0486, 0.13, 0.0695, 0.1135, 0.1388, 0.1276]

# xgBoost_means = [0.5589, 0.5908, 0.6091, 0.6231, 0.6293, 0.6126, 0.6596, 0.584, 0.6299, 0.6093, 0.6023, 0.6786, 0.6361, 0.574, 0.6514]
# xgBoost_stds = [0.0805, 0.1137, 0.0574, 0.0927, 0.0771, 0.0662, 0.0912, 0.1286, 0.0887, 0.0769, 0.0822, 0.0606, 0.112, 0.1032, 0.0799]

# # Option 4: Pandas DataFrame (best for complex analysis and seaborn)
# import pandas as pd

# # Create a long-format DataFrame
# conditions = ['1s_no', '1s_0.5', '1s_0.8', '2s_no', '2s_0.5', '2s_0.8', '3s_no', '3s_0.5', '3s_0.8', 
#             '4s_no', '4s_0.5', '4s_0.8', '5s_no', '5s_0.5', '5s_0.8']

# data = []
# # DecisionTree
# for i, condition in enumerate(conditions):
#     data.append({
#         'condition': condition,
#         'model': 'DecisionTree',
#         'mean': decisionTree_means[i],
#         'std': decisionTree_stds[i]
#     })

# # RandomForest  
# for i, condition in enumerate(conditions):
#     data.append({
#         'condition': condition,
#         'model': 'RandomForest',
#         'mean': randomForest_means[i],
#         'std': randomForest_stds[i]
#     })

# # XGBoost
# for i, condition in enumerate(conditions):
#     data.append({
#         'condition': condition,
#         'model': 'XGBoost',
#         'mean': xgBoost_means[i],
#         'std': xgBoost_stds[i]
#     })

# df = pd.DataFrame(data)

# # Usage with seaborn:
# sns.scatterplot(data=df, x='std', y='mean', hue='model')
