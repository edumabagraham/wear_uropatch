# %%
from combined_plots import *
from individual_plots import *

# %%
# Run the complete analysis
results = analyze_window_sizes(
file_path_2class="/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/2-class nested cross-validation.csv",
file_path_3class="/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/3-class nested cross-validation.csv"  
)

# Show all plots
plt.show()

# Access individual figures if needed
# results['2class_individual'].savefig('2class_window_comparison.png', dpi=300, bbox_inches='tight')
# results['2class_summary'].savefig('2class_summary.png', dpi=300, bbox_inches='tight')

# Print some statistics
print("\n=== ANALYSIS SUMMARY ===")
df_2class = results['2class_data']

print(f"\n2-Class Task:")
print(f"Best F1-Score: {df_2class['f1_mean'].max():.4f} "
        f"({df_2class.loc[df_2class['f1_mean'].idxmax(), 'window_size']} + "
        f"{df_2class.loc[df_2class['f1_mean'].idxmax(), 'model']})")
print(f"Best Accuracy: {df_2class['accuracy_mean'].max():.4f} "
        f"({df_2class.loc[df_2class['accuracy_mean'].idxmax(), 'window_size']} + "
        f"{df_2class.loc[df_2class['accuracy_mean'].idxmax(), 'model']})")

if '3class_data' in results:
        df_3class = results['3class_data']
        print(f"\n3-Class Task:")
        print(f"Best F1-Score: {df_3class['f1_mean'].max():.4f} "
        f"({df_3class.loc[df_3class['f1_mean'].idxmax(), 'window_size']} + "
        f"{df_3class.loc[df_3class['f1_mean'].idxmax(), 'model']})")
        print(f"Best Accuracy: {df_3class['accuracy_mean'].max():.4f} "
        f"({df_3class.loc[df_3class['accuracy_mean'].idxmax(), 'window_size']} + "
        f"{df_3class.loc[df_3class['accuracy_mean'].idxmax(), 'model']})")
# Out:
# Parsing 2-class classification results...
# Successfully parsed 45 configurations for 2-class task
#
# Creating 2-class individual window plots...
# Creating 2-class summary plots...
# Parsing 3-class classification results...
# Successfully parsed 45 configurations for 3-class task
#
# Creating 3-class individual window plots...
# Creating 3-class summary plots...
# === ANALYSIS SUMMARY ===
#
# 2-Class Task:
# Best F1-Score: 0.7202 (3s + RF)
# Best Accuracy: 0.7325 (3s + XGB)
#
# 3-Class Task:
# Best F1-Score: 0.5396 (5s_0.5 + XGB)
# Best Accuracy: 0.5853 (3s_0.8 + RF)

# %%
results = analyze_and_plot_window_sizes(
        file_path_2class="/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/2-class nested cross-validation.csv",
        file_path_3class="/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/3-class nested cross-validation.csv",  # optional
        output_dir="/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots",  # Directory to save plots
        dpi=300,                              # High resolution
        format='png',                         # Image format
        show_plots=True                      # Set to True if you want to display plots
    )
    
# Print summary of saved files
print("\n" + "="*80)
print("SUMMARY OF SAVED FILES")
print("="*80)
    
for task in results:
    print(f"\n{task.upper()} PLOTS:")
    for window_size, filepath in results[task]['saved_files'].items():
        print(f"  {window_size:8} → {filepath}")
    
# Save summary tables to CSV
if '2class' in results:
    results['2class']['summary'].to_csv(
        os.path.join("/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots", "2class_summary.csv"), 
        index=False
    )
    
if '3class' in results:
    results['3class']['summary'].to_csv(
        os.path.join("/home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots", "3class_summary.csv"), 
        index=False
    )
    
print(f"\n✓ Analysis complete! Check the 'individual_window_plots' directory.")
# Out:
# Parsing 2-class classification results...
# Successfully parsed 45 configurations for 2-class task
#
# Creating individual plots for 15 window sizes...
# ...
# [ 1/15] Creating plot for window size: 1s
#     ✓ Saved: /home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots/2class/2class_window_1s.png
# [ 2/15] Creating plot for window size: 1s_0.5
#     ✓ Saved: /home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots/2class/2class_window_1s-0.5.png
# [ 3/15] Creating plot for window size: 1s_0.8
#     ✓ Saved: /home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots/2class/2class_window_1s-0.8.png
# [ 4/15] Creating plot for window size: 2s
#     ✓ Saved: /home/edumaba/Public/MPhil_Thesis/Code/wear_uropatch/configuration_selection/window_size_plots/individuals_window_plots/2class/2class_window_2s.png
# ...
